# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# Set the path to the data
excel_path = "data/c14_master_v08.xlsx"

# %%
df = pd.read_excel(excel_path)
df.head()
# Out:
#    fid    socken  landskap        village_farm        raa_id site_type  \
# 0    1  Jörlanda  Bohuslän  Kyrkeby 3:34 m.fl.  Jörlanda 158   Boplats
# 1    2  Jörlanda  Bohuslän            Berg1:69  Jörlanda 185   Boplats
# 2    3  Jörlanda  Bohuslän            Berg1:69  Jörlanda 185   Boplats
# 3    4  Jörlanda  Bohuslän            Berg1:69  Jörlanda 185   Boplats
# 4    5  Jörlanda  Bohuslän            Berg1:69  Jörlanda 185   Boplats
#
#       site_id  uppdragsnummer    lab_no  c14_age_bp  c14_error  d13C  \
# 0  L1969:5267        103367.0  Ua-49252      2841.0       33.0  25.3
# 1  L1970:9431             NaN    T-8772      1720.0       80.0   NaN
# 2  L1970:9431             NaN    T-8773      2890.0      105.0   NaN
# 3  L1970:9431             NaN    T-8774      2015.0       75.0   NaN
# 4  L1970:9431             NaN    T-8775      1990.0       55.0   NaN
#
#    pMC_value  pMC_error c14_data_status comment assessed_relevant material  \
# 0        NaN        NaN              ok     NaN                 J   Träkol
# 1        NaN        NaN              ok     NaN                 J   Träkol
# 2        NaN        NaN              ok     NaN                 J   Träkol
# 3        NaN        NaN              ok     NaN                 J   Träkol
# 4        NaN        NaN              ok     NaN                 J   Träkol
#
#   species context_id  context_type  northing_3006  easting_3006  longitude  \
# 0    Lind      A1328       Kokgrop        6432029        312382  11.826064
# 1     NaN         A4  Stenpackning        6435710        313378  11.839973
# 2     NaN         A6  Stenpackning        6435710        313378  11.839973
# 3     NaN         A8          Härd        6435710        313378  11.839973
# 4     NaN        A23          Grop        6435710        313378  11.839973
#
#     latitude   location_precision  cal_68_min  cal_68_max  cal_95_min  \
# 0  57.990215  archaeological site      -930.0     -1046.0      -913.0
# 1  58.023646  archaeological site       414.0       247.0       541.0
# 2  58.023646  archaeological site      -930.0     -1214.0      -830.0
# 3  58.023646  archaeological site       117.0      -101.0       207.0
# 4  58.023646  archaeological site       110.0       -42.0       203.0
#
#    cal_95_max  median_cal_year            calibration_method  \
# 0     -1110.0           -997.0  HPD; IntCal20; rcarbon 1.5.0
# 1       132.0            339.0  HPD; IntCal20; rcarbon 1.5.0
# 2     -1381.0          -1086.0  HPD; IntCal20; rcarbon 1.5.0
# 3      -333.0             -5.0  HPD; IntCal20; rcarbon 1.5.0
# 4      -144.0             29.0  HPD; IntCal20; rcarbon 1.5.0
#
#   calibration_status           author  publication_year  \
# 0         calibrated    Åberg, Joakim            2015.0
# 1         calibrated  Johansson, Nils            1995.0
# 2         calibrated  Johansson, Nils            1995.0
# 3         calibrated  Johansson, Nils            1995.0
# 4         calibrated  Johansson, Nils            1995.0
#
#                                     title                            journal  \
# 0  Bergsmonument och boplatser i Jörlanda  Bohusläns museum, Rapport 2015:14
# 1          Tre boplatser i Spekerödsdalen            UV Väst, Rapport 1995:1
# 2          Tre boplatser i Spekerödsdalen            UV Väst, Rapport 1995:1
# 3          Tre boplatser i Spekerödsdalen            UV Väst, Rapport 1995:1
# 4          Tre boplatser i Spekerödsdalen            UV Väst, Rapport 1995:1
#
#   place_of_publication
# 0            Uddevalla
# 1           Kungsbacka
# 2           Kungsbacka
# 3           Kungsbacka
# 4           Kungsbacka

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30301 entries, 0 to 30300
# Data columns (total 38 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fid                   30301 non-null  int64
#  1   socken                30301 non-null  str
#  2   landskap              30301 non-null  str
#  3   village_farm          30244 non-null  str
#  4   raa_id                28460 non-null  str
#  5   site_type             30219 non-null  str
#  6   site_id               29963 non-null  str
#  7   uppdragsnummer        17681 non-null  float64
#  8   lab_no                30301 non-null  str
#  9   c14_age_bp            30185 non-null  float64
#  10  c14_error             30152 non-null  float64
#  11  d13C                  21439 non-null  float64
#  12  pMC_value             100 non-null    float64
#  13  pMC_error             99 non-null     float64
#  14  c14_data_status       30301 non-null  str
#  15  comment               3682 non-null   str
#  16  assessed_relevant     30106 non-null  str
#  17  material              30300 non-null  str
#  18  species               18240 non-null  str
#  19  context_id            26035 non-null  str
#  20  context_type          29795 non-null  str
#  21  northing_3006         30301 non-null  int64
#  22  easting_3006          30301 non-null  int64
#  23  longitude             30301 non-null  float64
#  24  latitude              30301 non-null  float64
#  25  location_precision    30301 non-null  str
#  26  cal_68_min            29731 non-null  float64
#  27  cal_68_max            29731 non-null  float64
#  28  cal_95_min            29731 non-null  float64
#  29  cal_95_max            29731 non-null  float64
#  30  median_cal_year       29731 non-null  float64
#  31  calibration_method    29731 non-null  str
#  32  calibration_status    30301 non-null  str
#  33  author                30301 non-null  str
#  34  publication_year      30269 non-null  float64
#  35  title                 30277 non-null  str
#  36  journal               29833 non-null  str
#  37  place_of_publication  29605 non-null  str
# dtypes: float64(14), int64(3), str(21)
# memory usage: 8.8 MB

# %%
df.describe(include='all')
# Out:
#                 fid   socken landskap      village_farm      raa_id site_type  \
# count   30301.00000    30301    30301             30244       28460     30219
# unique          NaN     1056       37              4998        5437       303
# top             NaN  Uppsala  Uppland  Lockarp 2:1 m fl  Lockarp 18   Boplats
# freq            NaN     1026     6042               223         223      8449
# mean    15151.00000      NaN      NaN               NaN         NaN       NaN
# std      8747.28959      NaN      NaN               NaN         NaN       NaN
# min         1.00000      NaN      NaN               NaN         NaN       NaN
# 25%      7576.00000      NaN      NaN               NaN         NaN       NaN
# 50%     15151.00000      NaN      NaN               NaN         NaN       NaN
# 75%     22726.00000      NaN      NaN               NaN         NaN       NaN
# max     30301.00000      NaN      NaN               NaN         NaN       NaN
#
#            site_id  uppdragsnummer    lab_no     c14_age_bp     c14_error  \
# count        29963    1.768100e+04     30301   30185.000000  30152.000000
# unique        6118             NaN     30291            NaN           NaN
# top     L1988:4693             NaN  Ua-86040            NaN           NaN
# freq           223             NaN         3            NaN           NaN
# mean           NaN    1.739642e+08       NaN    2140.700977     54.636973
# std            NaN    8.004354e+07       NaN    2033.402101     82.896531
# min            NaN    1.000180e+05       NaN      -1.000000     -1.000000
# 25%            NaN    2.004001e+08       NaN    1140.000000     30.000000
# 50%            NaN    2.012007e+08       NaN    1801.000000     40.000000
# 75%            NaN    2.018011e+08       NaN    2505.000000     70.000000
# max            NaN    2.020013e+09       NaN  100000.000000   9025.000000
#
#                 d13C   pMC_value  pMC_error c14_data_status  \
# count   21439.000000  100.000000  99.000000           30301
# unique           NaN         NaN        NaN               3
# top              NaN         NaN        NaN              ok
# freq             NaN         NaN        NaN           29731
# mean       20.249556  113.966000   0.979293             NaN
# std       190.911893   30.514774   3.138648             NaN
# min       -28.300000   80.900000   0.000000             NaN
# 25%         0.000000   99.997500   0.400000             NaN
# 50%        24.600000  103.105000   0.500000             NaN
# 75%        26.200000  116.450000   0.700000             NaN
# max     25386.000000  352.000000  30.000000             NaN
#
#                         comment assessed_relevant material species context_id  \
# count                      3682             30106    30300   18240      26035
# unique                     2058                 4       41     583      10503
# top     Daterar ej anläggningen                 J   Träkol    Tall         A1
# freq                        188             28364    21891    2928        718
# mean                        NaN               NaN      NaN     NaN        NaN
# std                         NaN               NaN      NaN     NaN        NaN
# min                         NaN               NaN      NaN     NaN        NaN
# 25%                         NaN               NaN      NaN     NaN        NaN
# 50%                         NaN               NaN      NaN     NaN        NaN
# 75%                         NaN               NaN      NaN     NaN        NaN
# max                         NaN               NaN      NaN     NaN        NaN
#
#        context_type  northing_3006  easting_3006     longitude      latitude  \
# count         29795   3.030100e+04  3.030100e+04  30301.000000  30301.000000
# unique         1053            NaN           NaN           NaN           NaN
# top            Härd            NaN           NaN           NaN           NaN
# freq           6966            NaN           NaN           NaN           NaN
# mean            NaN   6.486949e+06  5.128824e+05     15.303081     58.502299
# std             NaN   2.255938e+05  1.328164e+05      2.285725      2.020949
# min             NaN   4.653320e+05  2.788610e+05     11.154336      4.209866
# 25%             NaN   6.311431e+06  3.818210e+05     13.103535     56.924534
# 50%             NaN   6.501630e+06  5.126990e+05     15.219477     58.631743
# 75%             NaN   6.606790e+06  6.386760e+05     17.456184     59.576556
# max             NaN   7.556988e+06  6.878724e+06     83.176463     67.919657
#
#          location_precision    cal_68_min    cal_68_max    cal_95_min  \
# count                 30301  29731.000000  29731.000000  29731.000000
# unique                    2           NaN           NaN           NaN
# top     archaeological site           NaN           NaN           NaN
# freq                  29963           NaN           NaN           NaN
# mean                    NaN   -176.953180   -359.532811   -118.680334
# std                     NaN   1996.170029   2026.434700   1981.253296
# min                     NaN -44302.000000 -45589.000000 -43964.000000
# 25%                     NaN   -545.000000   -777.000000   -421.000000
# 50%                     NaN    325.000000    132.000000    375.000000
# 75%                     NaN    973.000000    775.000000    992.000000
# max                     NaN   1950.000000   1712.000000   1950.000000
#
#           cal_95_max  median_cal_year            calibration_method  \
# count   29731.000000     29731.000000                         29731
# unique           NaN              NaN                             1
# top              NaN              NaN  HPD; IntCal20; rcarbon 1.5.0
# freq             NaN              NaN                         29731
# mean     -419.985032      -266.149810                           NaN
# std      2048.037816      2008.703843                           NaN
# min    -46225.000000    -45016.000000                           NaN
# 25%      -798.000000      -636.000000                           NaN
# 50%        85.000000       233.000000                           NaN
# 75%       691.000000       860.500000                           NaN
# max      1701.000000      1852.000000                           NaN
#
#        calibration_status     author  publication_year            title  \
# count               30301      30301      30269.000000            30277
# unique                  3       2020               NaN             4498
# top            calibrated  Protokoll               NaN  C-14 Dateringar
# freq                29731        485               NaN              485
# mean                  NaN        NaN       1967.210810              NaN
# std                   NaN        NaN        354.604782              NaN
# min                   NaN        NaN          0.000000              NaN
# 25%                   NaN        NaN       1998.000000              NaN
# 50%                   NaN        NaN       2007.000000              NaN
# 75%                   NaN        NaN       2015.000000              NaN
# max                   NaN        NaN      20202.000000              NaN
#
#         journal place_of_publication
# count     29833                29605
# unique     4312                  140
# top     Stencil            Stockholm
# freq        546                 6401
# mean        NaN                  NaN
# std         NaN                  NaN
# min         NaN                  NaN
# 25%         NaN                  NaN
# 50%         NaN                  NaN
# 75%         NaN                  NaN
# max         NaN                  NaN

# %%
df.dropna(subset='species')['material'].unique()
# Out:
# <StringArray>
# [                'Träkol',            'Ben, brända',          'Förkolnat frö',
#               'Växtdelar',                   'Tand',    'Organisk beläggning',
#                     'Trä',           'Ben, obrända',           'Skalfragment',
#               'Animalier',                   'Bark',     'Frö (ej förkolnat)',
#                    'Horn',               'Fekalier',               'Kollagen',
#                   'Svamp',             'Kol i järn',     'Organiskt material',
#  'Sot/Organiskt material',                  'Harts',              'Järnslagg',
#                   'Okänd',                   'Bröd',               'Karbonat',
#               'Förkolnad',         'Skal/mollusker',               'Ben,horn',
#         'Krossad keramik',                   'Fisk']
# Length: 29, dtype: str

# %%
#pMC values

df_pmc = df.dropna(subset='pMC_value')
df_pmc
# Out:
#          fid     socken     landskap        village_farm         raa_id  \
# 74        75        Boo      Uppland      Boo 1:30, 11:3         Boo 22
# 751      752      Växjö      Småland         Domkyrkan 1      Växjö 170
# 835      836   Karlstad     Värmland           Kv Druvan    Karlstad 30
# 1223    1224  Björlanda     Bohuslän  Kvisljungeby 2:122  Björlanda 303
# 1608    1609  Gällivare     Lappland       Sakajärvi 2:4            NaN
# ...      ...        ...          ...                 ...            ...
# 29676  29677   Västerås  Västmanland         Stadsparken   Västerås 232
# 30026  30027    Lindome           Ha         Inseros 1:3            287
# 30027  30028    Lindome           Ha         Inseros 1:3            366
# 30063  30064   Mistelås           Sm         Villarp 1:7             89
# 30217  30218      Stala           Bo            Haga 1:4            393
#
#            site_type     site_id  uppdragsnummer    lab_no  c14_age_bp  \
# 74     Tegelindustri  L2017:1373     201300088.0  Ua-40545         NaN
# 751       Stadslager  L1953:1681     201700034.0  Ua-54631         NaN
# 835       Stadslager  L2007:9898     200400205.0  Ua-27875         0.0
# 1223   Boplatsområde  L1970:6811     201900585.0  Ua-63437         NaN
# 1608            Härd   L2018:327     201800424.0  Ua-62165         NaN
# ...              ...         ...             ...       ...         ...
# 29676     Stadslager   L2002:434     201801994.0  Ua-55311         NaN
# 30026     Fast fiske  L1969:4490        103330.0  Ua-47703         NaN
# 30027     Fast fiske   L1959:973        103330.0  Ua-47702         NaN
# 30063    Fossil åker  L1954:9018     201901235.0  Ua-65477         NaN
# 30217     Båtlänning   L1959:665     201400014.0  Ua-31263         NaN
#
#        c14_error  d13C  pMC_value  pMC_error  c14_data_status  \
# 74           NaN  25.0      104.5        0.5  c14_data_saknas
# 751          NaN   NaN      101.6        0.5  c14_data_saknas
# 835          0.0  25.3       99.7        0.4  c14_data_saknas
# 1223         NaN  24.1      106.1        0.4  c14_data_saknas
# 1608         NaN  13.4      101.6        0.6  c14_data_saknas
# ...          ...   ...        ...        ...              ...
# 29676        NaN  26.8      113.5        0.0  c14_data_saknas
# 30026        NaN  29.6       99.3        0.4  c14_data_saknas
# 30027        NaN  28.1       99.9        0.4  c14_data_saknas
# 30063        NaN  27.0      106.9        0.4  c14_data_saknas
# 30217        NaN  26.6      144.6        0.6  c14_data_saknas
#
#                        comment assessed_relevant      material   species  \
# 74                         NaN                 N         Mossa       NaN
# 751                        NaN                 N        Träkol       NaN
# 835                        NaN                 J        Träkol     Björk
# 1223   Daterar ej anläggningen                 N        Träkol        Al
# 1608   Daterar ej anläggningen                 N  Ben, obrända       NaN
# ...                        ...               ...           ...       ...
# 29676                      NaN                 N       Kol/sot       NaN
# 30026                      NaN                 J           Trä     Björk
# 30027                      NaN                 J           Trä  barrträd
# 30063                      NaN                 J        Träkol       NaN
# 30217  Daterar ej anläggningen                 N           Trä       NaN
#
#       context_id  context_type  northing_3006  easting_3006  longitude  \
# 74            L2         Lager        6579309        687654  18.296883
# 751          R31  Röjningsröse        6303851        488383  14.809389
# 835         8369      Stolphål        6583565        414665  13.497923
# 1223       A1000          Grop        6405020        310885  11.822228
# 1608         NaN          Härd        7450181        751891  20.798940
# ...          ...           ...            ...           ...        ...
# 29676         S4         Lager        6609051        587059  16.542816
# 30026        NaN          Påle        6388296        336143  12.257408
# 30027        NaN          Påle        6388269        336147  12.257493
# 30063       RR37  Röjningsröse        6312508        463485  14.399633
# 30217        NaN       Båtstöd        6448588        301098  11.621535
#
#         latitude   location_precision  cal_68_min  cal_68_max  cal_95_min  \
# 74     59.310833  archaeological site         NaN         NaN         NaN
# 751    56.878263  archaeological site         NaN         NaN         NaN
# 835    59.382118  archaeological site         NaN         NaN         NaN
# 1223   57.747355  archaeological site         NaN         NaN         NaN
# 1608   67.063229  archaeological site         NaN         NaN         NaN
# ...          ...                  ...         ...         ...         ...
# 29676  59.610546  archaeological site         NaN         NaN         NaN
# 30026  57.607233  archaeological site         NaN         NaN         NaN
# 30027  57.606992  archaeological site         NaN         NaN         NaN
# 30063  56.954738  archaeological site         NaN         NaN         NaN
# 30217  58.133789  archaeological site         NaN         NaN         NaN
#
#        cal_95_max  median_cal_year calibration_method calibration_status  \
# 74            NaN              NaN                NaN   not calibratable
# 751           NaN              NaN                NaN   not calibratable
# 835           NaN              NaN                NaN   not calibratable
# 1223          NaN              NaN                NaN   not calibratable
# 1608          NaN              NaN                NaN   not calibratable
# ...           ...              ...                ...                ...
# 29676         NaN              NaN                NaN   not calibratable
# 30026         NaN              NaN                NaN   not calibratable
# 30027         NaN              NaN                NaN   not calibratable
# 30063         NaN              NaN                NaN   not calibratable
# 30217         NaN              NaN                NaN   not calibratable
#
#                                         author  publication_year  \
# 74     Ljung, J-Å, Strucke, Ulf & Vinberg, Ann            2013.0
# 751                         Bondesson Hvid, Bo            2017.0
# 835             Karlsson, Martin & Knabe, Ebba            2006.0
# 1223                             Beckman, Anna            2020.0
# 1608                             Lindgren, Åsa            2018.0
# ...                                        ...               ...
# 29676                            Spjutj, Oskar            2017.0
# 30026                       Bergstrand, Thomas            2014.0
# 30027                       Bergstrand, Thomas            2014.0
# 30063                          Engman, Fredrik            2020.0
# 30217                           Lönn, Marianne            2014.0
#
#                                                    title  \
# 74     Tegelugnen i Boo. Medeltida tegeltillverkning ...
# 751    Arkeologisk förundersökning 2016, Växjö 13:32,...
# 835          Stadsarkeologi i kvarteret Druvan, Karlstad
# 1223                              En boplats i Björlanda
# 1608                              Aitik, en ny härd 2018
# ...                                                  ...
# 29676  Vikingatida kulturlager: Upprustning av Stadsp...
# 30026  Inseros. Fasta fiskeanläggningar i Västra Ingsjön
# 30027  Inseros. Fasta fiskeanläggningar i Västra Ingsjön
# 30063  Arkeologisk förundersökning. Del av fornlämnin...
# 30217  Projekt Köpstad Orust. Bohuslän, Stala socken,...
#
#                                                  journal place_of_publication
# 74                                    UV Rapport 2013:27            Stockholm
# 751                       CMB Uppdragsarkeologi, 2017:15        Löddeköppinge
# 835    UV Bergslagen, Dokumentation av fältarbetsfase...            Stockholm
# 1223   Kulturmiljö, Förvaltningen för kulturutvecklin...           Vänersborg
# 1608                  Norrbottens museum, Rapport 2019:2                Luleå
# ...                                                  ...                  ...
# 29676        Stiftelsen Kulturmiljövård, Rapport 2017:41             Västerås
# 30026                   Bohusläns museum, Rapport 2014:9            Uddevalla
# 30027                   Bohusläns museum, Rapport 2014:9            Uddevalla
# 30063              SWECO RAPPORT Uppdragsnummer 13009305            Stockholm
# 30217                                 Uv Rapport 2014:27             Möölndal
#
# [100 rows x 38 columns]

# %%
# save pMC data (all instances with pMC_value being non-null)
# we will assume it is a subset of data where a measurement was done, unlike the rest of the data where this value is null

df_pmc.to_csv('output/strucke_v8_pMC_values.csv')

# %%
#remaining

df_no_pmc = df[df['pMC_value'].isna()].drop(columns=['pMC_value', 'pMC_error'])
df_no_pmc.describe(include='all')
# Out:
#                  fid   socken landskap      village_farm      raa_id  \
# count   30201.000000    30201    30201             30145       28372
# unique           NaN     1054       37              4990        5427
# top              NaN  Uppsala  Uppland  Lockarp 2:1 m fl  Lockarp 18
# freq             NaN     1024     6030               223         223
# mean    15147.466177      NaN      NaN               NaN         NaN
# std      8750.229094      NaN      NaN               NaN         NaN
# min         1.000000      NaN      NaN               NaN         NaN
# 25%      7566.000000      NaN      NaN               NaN         NaN
# 50%     15144.000000      NaN      NaN               NaN         NaN
# 75%     22733.000000      NaN      NaN               NaN         NaN
# max     30301.000000      NaN      NaN               NaN         NaN
#
#        site_type     site_id  uppdragsnummer    lab_no     c14_age_bp  \
# count      30120       29869    1.760600e+04     30201   30158.000000
# unique       303        6106             NaN     30191            NaN
# top      Boplats  L1988:4693             NaN  Ua-86040            NaN
# freq        8429         223             NaN         3            NaN
# mean         NaN         NaN    1.738358e+08       NaN    2142.600438
# std          NaN         NaN    7.889315e+07       NaN    2033.318427
# min          NaN         NaN    1.000180e+05       NaN      -1.000000
# 25%          NaN         NaN    2.004001e+08       NaN    1140.000000
# 50%          NaN         NaN    2.012007e+08       NaN    1803.500000
# 75%          NaN         NaN    2.018011e+08       NaN    2505.000000
# max          NaN         NaN    2.020013e+09       NaN  100000.000000
#
#            c14_error          d13C c14_data_status                  comment  \
# count   30124.000000  21373.000000           30201                     3655
# unique           NaN           NaN               3                     2046
# top              NaN           NaN              ok  Daterar ej anläggningen
# freq             NaN           NaN           29730                      176
# mean       54.685035     20.246425             NaN                      NaN
# std        82.919346    191.205376             NaN                      NaN
# min        -1.000000    -28.300000             NaN                      NaN
# 25%        30.000000      0.000000             NaN                      NaN
# 50%        40.000000     24.600000             NaN                      NaN
# 75%        70.000000     26.200000             NaN                      NaN
# max      9025.000000  25386.000000             NaN                      NaN
#
#        assessed_relevant material species context_id context_type  \
# count              30006    30200   18177      25953        29696
# unique                 4       39     581      10480         1048
# top                    J   Träkol    Tall         A1         Härd
# freq               28322    21841    2920        712         6954
# mean                 NaN      NaN     NaN        NaN          NaN
# std                  NaN      NaN     NaN        NaN          NaN
# min                  NaN      NaN     NaN        NaN          NaN
# 25%                  NaN      NaN     NaN        NaN          NaN
# 50%                  NaN      NaN     NaN        NaN          NaN
# 75%                  NaN      NaN     NaN        NaN          NaN
# max                  NaN      NaN     NaN        NaN          NaN
#
#         northing_3006  easting_3006     longitude      latitude  \
# count    3.020100e+04  3.020100e+04  30201.000000  30201.000000
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean     6.486599e+06  5.128228e+05     15.301778     58.499172
# std      2.253200e+05  1.327954e+05      2.284450      2.018586
# min      4.653320e+05  2.788610e+05     11.154336      4.209866
# 25%      6.311270e+06  3.817780e+05     13.102906     56.923493
# 50%      6.501320e+06  5.126990e+05     15.219477     58.631743
# 75%      6.606722e+06  6.385790e+05     17.456184     59.575896
# max      7.556988e+06  6.878724e+06     83.176463     67.919657
#
#          location_precision    cal_68_min    cal_68_max    cal_95_min  \
# count                 30201  29730.000000  29730.000000  29730.000000
# unique                    2           NaN           NaN           NaN
# top     archaeological site           NaN           NaN           NaN
# freq                  29869           NaN           NaN           NaN
# mean                    NaN   -177.007770   -359.589573   -118.733838
# std                     NaN   1996.181408   2026.445146   1981.265138
# min                     NaN -44302.000000 -45589.000000 -43964.000000
# 25%                     NaN   -545.000000   -777.000000   -421.000000
# 50%                     NaN    325.000000    132.000000    375.000000
# 75%                     NaN    973.000000    775.000000    992.000000
# max                     NaN   1950.000000   1712.000000   1950.000000
#
#           cal_95_max  median_cal_year            calibration_method  \
# count   29730.000000     29730.000000                         29730
# unique           NaN              NaN                             1
# top              NaN              NaN  HPD; IntCal20; rcarbon 1.5.0
# freq             NaN              NaN                         29730
# mean     -420.043054      -266.206256                           NaN
# std      2048.047824      2008.714047                           NaN
# min    -46225.000000    -45016.000000                           NaN
# 25%      -798.000000      -636.000000                           NaN
# 50%        85.000000       233.000000                           NaN
# 75%       691.000000       860.000000                           NaN
# max      1701.000000      1852.000000                           NaN
#
#        calibration_status     author  publication_year            title  \
# count               30201      30201      30169.000000            30177
# unique                  3       2019               NaN             4490
# top            calibrated  Protokoll               NaN  C-14 Dateringar
# freq                29730        485               NaN              485
# mean                  NaN        NaN       1967.065564              NaN
# std                   NaN        NaN        355.182724              NaN
# min                   NaN        NaN          0.000000              NaN
# 25%                   NaN        NaN       1998.000000              NaN
# 50%                   NaN        NaN       2007.000000              NaN
# 75%                   NaN        NaN       2015.000000              NaN
# max                   NaN        NaN      20202.000000              NaN
#
#         journal place_of_publication
# count     29733                29506
# unique     4304                  140
# top     Stencil            Stockholm
# freq        546                 6380
# mean        NaN                  NaN
# std         NaN                  NaN
# min         NaN                  NaN
# 25%         NaN                  NaN
# 50%         NaN                  NaN
# 75%         NaN                  NaN
# max         NaN                  NaN

# %%
df_c14_data_saknas = df_no_pmc[df_no_pmc['c14_data_status']=='c14_data_saknas']
df_c14_data_saknas
# Out:
#          fid              socken       landskap      village_farm  \
# 100      101                Våmb  Västergötland        Våmb 30:10
# 344      345  Husby-Ärlinghundra        Uppland  Måby 2:7 "Maren"
# 345      346  Husby-Ärlinghundra        Uppland  Måby 2:7 "Maren"
# 346      347  Husby-Ärlinghundra        Uppland  Måby 2:7 "Maren"
# 644      645               Växjö        Småland      Biskopshagen
# ...      ...                 ...            ...               ...
# 30250  30251             Tossene             Bo         Torp 1:13
# 30251  30252             Tossene             Bo         Torp 1:13
# 30262  30263             Tossene             Bo         Torp 1:13
# 30265  30266             Tossene             Bo         Torp 1:13
# 30266  30267             Tossene             Bo         Torp 1:13
#
#                        raa_id                   site_type     site_id  \
# 100                   Våmb 52  Område med fossil åkermark  L1961:6180
# 344    Husby-Ärlinghundra 138         Lägenhetsbebyggelse  L2016:1375
# 345    Husby-Ärlinghundra 138         Lägenhetsbebyggelse  L2016:1375
# 346    Husby-Ärlinghundra 138         Lägenhetsbebyggelse  L2016:1375
# 644                 Växjö 358     Grav- och boplatsområde  L1953:8423
# ...                       ...                         ...         ...
# 30250                    1018                     Boplats  L1960:8757
# 30251                    1018                     Boplats  L1960:8757
# 30262                    1018                     Boplats  L1960:8757
# 30265                    1018                     Boplats  L1960:8757
# 30266                    1018                     Boplats  L1960:8757
#
#        uppdragsnummer       lab_no  c14_age_bp  c14_error  d13C  \
# 100       201600692.0  ICA-Okänd 3         0.0       40.0   NaN
# 344               NaN      ST13802       250.0        0.0   0.0
# 345               NaN      ST13803       250.0        0.0   0.0
# 346               NaN      ST13804       250.0        0.0   0.0
# 644               NaN  PozOkänd 11         NaN        NaN   NaN
# ...               ...          ...         ...        ...   ...
# 30250     202500158.0    Poz-40188         NaN        NaN   NaN
# 30251     202500158.0    Poz-40189         NaN        NaN   NaN
# 30262     202500158.0     Ua-40187         NaN        NaN   NaN
# 30265     202500158.0     Ua-44252         NaN        NaN   NaN
# 30266     202500158.0     Ua-44253         NaN        NaN   NaN
#
#        c14_data_status                                            comment  \
# 100    c14_data_saknas                                                NaN
# 344    c14_data_saknas                                                NaN
# 345    c14_data_saknas                                                NaN
# 346    c14_data_saknas                                                NaN
# 644    c14_data_saknas  Labnr och 14Cålder saknas i rapport Poz? 1460-...
# ...                ...                                                ...
# 30250  c14_data_saknas  14C-ålder saknas i rapport. Kal. 2 sigma 1375-...
# 30251  c14_data_saknas  14C-ålder saknas i rapport kal. 2 sigma 1730-1...
# 30262  c14_data_saknas   Labnr saknas i rapport Kal. 2 sigma 1680-1515 BC
# 30265  c14_data_saknas  14C-ålder saknas i rapport kaol. 2 sigma 1670-...
# 30266  c14_data_saknas      14C-ålder saknas i  rapport Kal. 1690-1510 BC
#
#       assessed_relevant     material species context_id    context_type  \
# 100                   J       Träkol     NaN       A114           Lager
# 344                   J       Träkol     NaN      A 264        Stolphål
# 345                   J       Träkol     NaN      A 711            Grop
# 346                   J       Träkol     NaN      A 826            Grop
# 644                 NaN       Träkol     NaN      A3829        Stolphål
# ...                 ...          ...     ...        ...             ...
# 30250                 J  Ben, brända     NaN     A16735         Kokgrop
# 30251                 J  Ben, brända     NaN     A21351        Stolphål
# 30262                 J  Ben, brända     NaN     A17128     Kokgrop/ugn
# 30265                 J  Ben, brända     NaN     A21897  Skärvstensflak
# 30266                 J  Ben, brända     NaN     A21897  Skärvstensflak
#
#        northing_3006  easting_3006  longitude   latitude   location_precision  \
# 100          6473028        429916  13.801147  58.392444  archaeological site
# 344          6613144        664703  17.920385  59.623851  archaeological site
# 345          6613144        664703  17.920385  59.623851  archaeological site
# 346          6613144        664703  17.920385  59.623851  archaeological site
# 644          6302567        487812  14.800081  56.866713  archaeological site
# ...              ...           ...        ...        ...                  ...
# 30250        6484551        288035  11.367227  58.450088  archaeological site
# 30251        6484551        288035  11.367227  58.450088  archaeological site
# 30262        6484551        288035  11.367227  58.450088  archaeological site
# 30265        6484551        288035  11.367227  58.450088  archaeological site
# 30266        6484551        288035  11.367227  58.450088  archaeological site
#
#        cal_68_min  cal_68_max  cal_95_min  cal_95_max  median_cal_year  \
# 100           NaN         NaN         NaN         NaN              NaN
# 344           NaN         NaN         NaN         NaN              NaN
# 345           NaN         NaN         NaN         NaN              NaN
# 346           NaN         NaN         NaN         NaN              NaN
# 644           NaN         NaN         NaN         NaN              NaN
# ...           ...         ...         ...         ...              ...
# 30250         NaN         NaN         NaN         NaN              NaN
# 30251         NaN         NaN         NaN         NaN              NaN
# 30262         NaN         NaN         NaN         NaN              NaN
# 30265         NaN         NaN         NaN         NaN              NaN
# 30266         NaN         NaN         NaN         NaN              NaN
#
#       calibration_method calibration_status  \
# 100                  NaN   not calibratable
# 344                  NaN   not calibratable
# 345                  NaN   not calibratable
# 346                  NaN   not calibratable
# 644                  NaN   not calibratable
# ...                  ...                ...
# 30250                NaN   not calibratable
# 30251                NaN   not calibratable
# 30262                NaN   not calibratable
# 30265                NaN   not calibratable
# 30266                NaN   not calibratable
#
#                                               author  publication_year  \
# 100                                      Berger, Åsa            2016.0
# 344                 Hallesjö, Maria & Hamilton, John            1997.0
# 345                 Hallesjö, Maria & Hamilton, John            1997.0
# 346                 Hallesjö, Maria & Hamilton, John            1997.0
# 644                                    Kadefors, Ola            2006.0
# ...                                              ...               ...
# 30250  Kegel, K., Sörman, A., Wessman, A. & Ling, J.            2013.0
# 30251  Kegel, K., Sörman, A., Wessman, A. & Ling, J.            2013.0
# 30262  Kegel, K., Sörman, A., Wessman, A. & Ling, J.            2013.0
# 30265  Kegel, K., Sörman, A., Wessman, A. & Ling, J.            2013.0
# 30266  Kegel, K., Sörman, A., Wessman, A. & Ling, J.            2013.0
#
#                                                    title  \
# 100    Stensättningar och järnframställning - Arkeolo...
# 344                    En boplats och ett torp vid Maren
# 345                    En boplats och ett torp vid Maren
# 346                    En boplats och ett torp vid Maren
# 644                   Boplatsen i Kvarteren Biskopshagen
# ...                                                  ...
# 30250  Arkeologisk undersökning av RAÄ 1018 vid hällr...
# 30251  Arkeologisk undersökning av RAÄ 1018 vid hällr...
# 30262  Arkeologisk undersökning av RAÄ 1018 vid hällr...
# 30265  Arkeologisk undersökning av RAÄ 1018 vid hällr...
# 30266  Arkeologisk undersökning av RAÄ 1018 vid hällr...
#
#                                             journal place_of_publication
# 100             Arkeologikonsult, Rapport 2016:2941       Upplands Väsby
# 344                   UV Stockholm, Rapport 1997:33            Stockholm
# 345                   UV Stockholm, Rapport 1997:33            Stockholm
# 346                   UV Stockholm, Rapport 1997:33            Stockholm
# 644                Smålands museum, Rapport 2006:51                Växjö
# ...                                             ...                  ...
# 30250  GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
# 30251  GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
# 30262  GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
# 30265  GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
# 30266  GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
#
# [470 rows x 36 columns]

# %%
#values with no data for c14 nor cal(68 nor 95), where only material, species and author exist
df_c14_data_saknas[df_c14_data_saknas['c14_age_bp'].isna()]
# Out:
#          fid        socken       landskap               village_farm  \
# 644      645         Växjö        Småland               Biskopshagen
# 812      813         Växjö        Småland               Biskopshagen
# 813      814         Växjö        Småland               Biskopshagen
# 814      815         Växjö        Småland               Biskopshagen
# 1492    1493         Sunne       Värmland               Gylleby 1:11
# 1493    1494         Sunne       Värmland               Torvnäs 1:11
# 1494    1495         Sunne       Värmland               Torvnäs 1:11
# 1495    1496         Sunne       Värmland               Häljeby 1:58
# 1496    1497         Sunne       Värmland               Torvnäs 1:11
# 1497    1498         Sunne       Värmland               Torvnäs 1:11
# 1498    1499         Sunne       Värmland               Torvnäs 1:11
# 1499    1500         Sunne       Värmland               Torvnäs 1:11
# 1500    1501         Sunne       Värmland               Torvnäs 1:11
# 1501    1502         Sunne       Värmland               Torvnäs 1:11
# 1502    1503         Sunne       Värmland  Sunne Klockargården 18:46
# 1503    1504         Sunne       Värmland               Torvnäs 1:42
# 1504    1505         Sunne       Värmland               Torvnäs 1:42
# 15404  Västra Karup 504                Bytomt/gårdstomt  L1988:8552
# 18484          Öjaby 66                   Skärvstenshög  L1953:7652
# 18905    Nederluleå 330                      Stadslager  L1992:4875
# 19550    Eskilsäter 223                   Boplatsområde  L2007:3824
# 19551    Eskilsäter 223                   Boplatsområde  L2007:3824
# 19729       Sorunda 969                         Boplats  L2013:7601
# 20438         Kjula 295                         Boplats  L1982:2775
# 22288     Redslared 115      Område med fossil åkermark  L1964:1130
# 26479          Sura 169  Område med skogsbrukslämningar  L2002:8199
# 29510      Västerås 261                   Boplatsområde  L2003:9772
# 30250              1018                         Boplats  L1960:8757
# 30251              1018                         Boplats  L1960:8757
# 30262              1018                         Boplats  L1960:8757
# 30265              1018                         Boplats  L1960:8757
# 30266              1018                         Boplats  L1960:8757
#
#        uppdragsnummer       lab_no  c14_age_bp  c14_error  d13C  \
# 644               NaN  PozOkänd 11         NaN        NaN   NaN
# 812               NaN    UaOkänd64         NaN        NaN   NaN
# 813               NaN    UaOkänd65         NaN        NaN   NaN
# 814               NaN    UaOkänd66         NaN        NaN   NaN
# 1492      200300137.0     Ua-22050         NaN        NaN   NaN
# 1493      200300137.0     Ua-22046         NaN        NaN   NaN
# 1494      200300137.0     Ua-22045         NaN        NaN   NaN
# 1495      200300137.0     Ua-22049         NaN        NaN   NaN
# 1496      200300137.0     Ua-22044         NaN        NaN   NaN
# 1497      201100276.0     Ua-43017         NaN        NaN   NaN
# 1498      201100276.0     Ua-43018         NaN        NaN   NaN
# 1499      201100274.0  Ua-okänd104         NaN        NaN   NaN
# 1500      201100274.0  Ua-okänd105         NaN        NaN   NaN
# 1501      201100274.0  Ua-okänd106         NaN        NaN   NaN
# 1502      200300137.0     Ua-22043         NaN        NaN   NaN
# 1503      200300137.0     Ua-22047         NaN        NaN   NaN
# 1504      200300137.0     Ua-22048         NaN        NaN   NaN
# 2652      201802127.0     Ua-53262         NaN        NaN   NaN
# 2654      201802127.0     Ua-53264         NaN        NaN   NaN
# 2660      201802127.0     Ua-53271         NaN        NaN   NaN
# 3929              NaN     Ua-10176         NaN       70.0   NaN
# 9365         103721.0     Ua-32273         NaN        NaN   NaN
# 12452     201400500.0     Ua-55823         NaN        NaN   NaN
# 13093     200400375.0     LuS-7709         NaN        NaN   NaN
# 13104     200400375.0     Ua-24702         NaN        NaN   NaN
# 13672     201300898.0     Ua-43114         NaN        NaN   NaN
# 14414     202200708.0  SUERC-84952         NaN        NaN   NaN
# 14418     202200708.0     Ua-60661         NaN        NaN   NaN
# 15404     201400859.0    UGA-15402         NaN        NaN   NaN
# 18484     202001192.0     Ua-69468         NaN        NaN   NaN
# 18905             NaN     Ua-66013         NaN        NaN   NaN
# 19550     201000271.0   Ua-okänd93         NaN        NaN   NaN
# 19551     201000271.0   Ua-okänd94         NaN        NaN   NaN
# 19729             NaN     16P/0267         NaN        NaN   NaN
# 20438     201300230.0     Ua-45097         NaN        NaN   NaN
# 22288             NaN     Ua-35589         NaN        NaN  26.7
# 26479     201300109.0  Beta-375048         NaN        NaN  26.8
# 29510     201200195.0     Ua-39455         NaN        NaN   NaN
# 30250     202500158.0    Poz-40188         NaN        NaN   NaN
# 30251     202500158.0    Poz-40189         NaN        NaN   NaN
# 30262     202500158.0     Ua-40187         NaN        NaN   NaN
# 30265     202500158.0     Ua-44252         NaN        NaN   NaN
# 30266     202500158.0     Ua-44253         NaN        NaN   NaN
#
#        c14_data_status                                            comment  \
# 644    c14_data_saknas  Labnr och 14Cålder saknas i rapport Poz? 1460-...
# 812    c14_data_saknas  Labnr och 14Cålder saknas i rapport Ua? 1740-1...
# 813    c14_data_saknas   Labnr och 14Cålder sknas i rapport Ua? 760-400BC
# 814    c14_data_saknas     Labnr och 14Cålder saknas i rapport 390-160 BC
# 1492   c14_data_saknas  14C-åler saknas i rapport Kal 2 sigma 400-200 ...
# 1493   c14_data_saknas  14C-ålder saknas i rapport Kal 2 sigma 101-820...
# 1494   c14_data_saknas  14C-ålder saknas i rapport Kal 2 sigma 1080-83...
# 1495   c14_data_saknas  14C-ålder saknas i rapport Kal 2 sigma 1210-89...
# 1496   c14_data_saknas  14C-ålder saknas i rasapport Kal 2 sigma 400-2...
# 1497   c14_data_saknas           14-Cålder saknas i rapport Kal 350-50 BC
# 1498   c14_data_saknas         14C-ålder saknas i rapport Kal 890-1020 AD
# 1499   c14_data_saknas  Labnr och 14C-ålder saknas i rapport Kal 11-11...
# 1500   c14_data_saknas  Labnr och 14Cålder saknas i rapport Kal 780-98...
# 1501   c14_data_saknas    Labnr och 14C-ålder saknas i rapport Kal 108 år
# 1502   c14_data_saknas  14C-ålder saknas i rrapport Kal 2 sigma 410-20...
# 1503   c14_data_saknas  14C-ålder saknas i rapport Kal 2 sigma 1440-16...
# 1504   c14_data_saknas  14C-ålder saknas i rapport Kal 2 sigma 900-116...
# 2652   c14_data_saknas                                Utelämnad i rapport
# 2654   c14_data_saknas                                Utelämnad i rapport
# 2660   c14_data_saknas                                                NaN
# 3929   c14_data_saknas                              14C-ålder fallit bort
# 9365   c14_data_saknas                                                NaN
# 12452  c14_data_saknas                                                NaN
# 13093  c14_data_saknas       14C-ålder saknas i rapport Wigglematch 1433-
# 13104  c14_data_saknas  14C-ålder saknas i rappot Kal 2 sigma 810-1020...
# 13672  c14_data_saknas                                                NaN
# 14414  c14_data_saknas            14C-ålder saknas i rapport kal. 531-605
# 14418  c14_data_saknas                 14C-ålder saknas i rapport Dat fvt
# 15404  c14_data_saknas                                             Modern
# 18484  c14_data_saknas                                                NaN
# 18905  c14_data_saknas                                                NaN
# 19550  c14_data_saknas  14C-ålder saknas i rapport kal 2 sigma 170 BC-...
# 19551  c14_data_saknas     Labnr sakknas i rapport kla 2 sigma 430-620 AD
# 19729  c14_data_saknas                                                NaN
# 20438  c14_data_saknas                                                NaN
# 22288  c14_data_saknas                   Modern 14Cålder saknas i rapport
# 26479  c14_data_saknas                                     år 1950+-20-30
# 29510  c14_data_saknas                                                NaN
# 30250  c14_data_saknas  14C-ålder saknas i rapport. Kal. 2 sigma 1375-...
# 30251  c14_data_saknas  14C-ålder saknas i rapport kal. 2 sigma 1730-1...
# 3929          NaN         NaN         NaN         NaN              NaN
# 9365          NaN         NaN         NaN         NaN              NaN
# 12452         NaN         NaN         NaN         NaN              NaN
# 13093         NaN         NaN         NaN         NaN              NaN
# 13104         NaN         NaN         NaN         NaN              NaN
# 13672         NaN         NaN         NaN         NaN              NaN
# 14414         NaN         NaN         NaN         NaN              NaN
# 14418         NaN         NaN         NaN         NaN              NaN
# 15404         NaN         NaN         NaN         NaN              NaN
# 18484         NaN         NaN         NaN         NaN              NaN
# 18905         NaN         NaN         NaN         NaN              NaN
# 19550         NaN         NaN         NaN         NaN              NaN
# 19551         NaN         NaN         NaN         NaN              NaN
# 19729         NaN         NaN         NaN         NaN              NaN
# 20438         NaN         NaN         NaN         NaN              NaN
# 22288         NaN         NaN         NaN         NaN              NaN
# 26479         NaN         NaN         NaN         NaN              NaN
# 29510         NaN         NaN         NaN         NaN              NaN
# 30250         NaN         NaN         NaN         NaN              NaN
# 30251         NaN         NaN         NaN         NaN              NaN
# 30262         NaN         NaN         NaN         NaN              NaN
# 30265         NaN         NaN         NaN         NaN              NaN
# 30266         NaN         NaN         NaN         NaN              NaN
#
#       calibration_method calibration_status  \
# 644                  NaN   not calibratable
# 812                  NaN   not calibratable
# 813                  NaN   not calibratable
# 814                  NaN   not calibratable
# 1492                 NaN   not calibratable
# 1493                 NaN   not calibratable
# 1494                 NaN   not calibratable
# 1495                 NaN   not calibratable
# 1496                 NaN   not calibratable
# 1497                 NaN   not calibratable
# 1498                 NaN   not calibratable
# 1499                 NaN   not calibratable
# 1500                 NaN   not calibratable
# 1501                 NaN   not calibratable
# 1502                 NaN   not calibratable
# 1503                 NaN   not calibratable
# 1504                 NaN   not calibratable
# 2652                 NaN   not calibratable
# 2654                 NaN   not calibratable
# 2660                 NaN   not calibratable
# 3929                 NaN   not calibratable
# 9365                 NaN   not calibratable
# 12452                NaN   not calibratable
# 13093                NaN   not calibratable
# 13104                NaN   not calibratable
# 13672                NaN   not calibratable
# 14414                NaN   not calibratable
# 14418                NaN   not calibratable
# 15404                NaN   not calibratable
# 18484                NaN   not calibratable
# 18905                NaN   not calibratable
# 19550                NaN   not calibratable
# 19551                NaN   not calibratable
# 19729                NaN   not calibratable
# 20438                NaN   not calibratable
# 22288                NaN   not calibratable
# 26479                NaN   not calibratable
# 29510                NaN   not calibratable
# 30250                NaN   not calibratable
# 30251                NaN   not calibratable
# 30262                NaN   not calibratable
# 30265                NaN   not calibratable
# 30266                NaN   not calibratable
#
#                                                   author  publication_year  \
# 644                                        Kadefors, Ola            2006.0
# 812                                        Kadefors, Ola            2006.0
# 813                                        Kadefors, Ola            2006.0
# 814                                        Kadefors, Ola            2006.0
# 1492                                        Olsson, Hans            2004.0
# 1493                                        Olsson, Hans            2004.0
# 1494                                        Olsson, Hans            2004.0
# 1495                                        Olsson, Hans            2004.0
# 1496                                        Olsson, Hans            2004.0
# 1497                                        Olsson, Hans            2012.0
# 1498                                        Olsson, Hans            2012.0
# 1499                                   Forssell, Ellinor            2012.0
# 1500                                   Forssell, Ellinor            2012.0
# 22288  Länsstyrelsen i Västra Götalands län, Rapport ...             Göteborg
# 26479                                 UV Rapport 2014:70            Stockholm
# 29510                               SAU, Rapport 2012:13              Uppsala
# 30250       GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
# 30251       GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
# 30262       GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
# 30265       GOTARC serie D Arkeologiska rapporter no 99.             Göteborg
# 30266       GOTARC serie D Arkeologiska rapporter no 99.             Göteborg

# %%
df_c14_data_saknas.to_csv('output/strucke_v8_no_c14_data.csv')

# %%
df[df['raa_id'].isna() & df['site_id'].isna()]
# Out:
#          fid     socken  landskap                        village_farm raa_id  \
# 1491    1492      Mosjö     Närke                           Marieberg    NaN
# 1596    1597  Gällivare  Lappland    Kronoöverloppsmark 2:1 Lappviken    NaN
# 1597    1598  Gällivare  Lappland    Kronoöverloppsmark 2:1 Lappviken    NaN
# 1598    1599  Gällivare  Lappland  Kronoöverloppsmark 2:1 Luotosuollo    NaN
# 1599    1600  Gällivare  Lappland  Kronoöverloppsmark 2:1 Luotosuollo    NaN
# ...      ...        ...       ...                                 ...    ...
# 28990  28991    Uppsala   Uppland                         Ulls väg 31    NaN
# 28991  28992    Uppsala   Uppland                        Ulltuna 2:23    NaN
# 29186  29187    Uppsala   Uppland                          Emblas väg    NaN
# 29188  29189    Uppsala   Uppland                      Vattholmavägen    NaN
# 30229  30230       Torp        Bo                          Ström 1:61    NaN
#
#       site_type site_id  uppdragsnummer    lab_no  c14_age_bp  c14_error  \
# 1491        NaN     NaN             NaN   Ua-9615       390.0       70.0
# 1596        NaN     NaN             NaN   ST11446       905.0      190.0
# 1597        NaN     NaN             NaN   ST11448       990.0       70.0
# 1598      Viste     NaN             NaN    ST1851       875.0       65.0
# 1599      Viste     NaN             NaN    ST1852       810.0       65.0
# ...         ...     ...             ...       ...         ...        ...
# 28990   Kokgrop     NaN     201300122.0  Ua-42008      1810.0       30.0
# 28991      Grop     NaN     201300122.0  Ua-42010      3188.0       48.0
# 29186   Boplats     NaN             NaN   Ua-5379      1640.0       60.0
# 29188   Boplats     NaN             NaN   Ua-5381      1390.0       60.0
# 30229    Hägnad     NaN     201400072.0  Ua-31262       937.0       31.0
#
#         d13C  pMC_value  pMC_error c14_data_status  \
# 1491   25.11        NaN        NaN              ok
# 1596   27.40        NaN        NaN              ok
# 1597   27.30        NaN        NaN              ok
# 1598    0.00        NaN        NaN              ok
# 1599    0.00        NaN        NaN              ok
# ...      ...        ...        ...             ...
# 28990  23.40        NaN        NaN              ok
# 28991  28.30        NaN        NaN              ok
# 29186   0.00        NaN        NaN              ok
# 29188   0.00        NaN        NaN              ok
# 30229  26.50        NaN        NaN              ok
#
#                                                  comment assessed_relevant  \
# 1491   Antagligen felaktigt fornlämningsnummer angive...                 J
# 1596                          Saknas i Fornsök Lappviken                 J
# 1597                          Saknas i Fornsök Lappviken                 J
# 1598   Oklart vilken fornlämning och position. Inlämn...                 L
# 1599   Oklart vilken fornlämning och position. Inlämn...                 J
# ...                                                  ...               ...
# 28990  Hulth, Helena & Andersson, Fredrk             213.0
# 28991  Hulth, Helena & Andersson, Fredrk             213.0
# 29186             Roslund-Forenius, Ylva            1996.0
# 29188             Roslund-Forenius, Ylva            1996.0
# 30229                   Nordqvist, Bengt            2014.0
#
#                                                    title  \
# 1491           Fjärrvärmeledning mellan Örebro och Kumla
# 1596                                              Sirkas
# 1597                                              Sirkas
# 1598                                              Sirkas
# 1599                                              Sirkas
# ...                                                  ...
# 28990  Förhistoriska utsnitt i Ultuna. Arkeologiska s...
# 28991  Förhistoriska utsnitt i Ultuna. Arkeologiska s...
# 29186                                      Gamla Uppsala
# 29188                                      Gamla Uppsala
# 30229  VA-ledning mellan Henån och Slussen. Arkeologi...
#
#                                                  journal place_of_publication
# 1491   Riksantikvarieämbetet Arkeologiska undersöknin...            Stockholm
# 1596        Studia archaeologica Universitatis Umensis 6                 Umeå
# 1597        Studia archaeologica Universitatis Umensis 6                 Umeå
# 1598        Studia archaeologica Universitatis Umensis 6                 Umeå
# 1599        Studia archaeologica Universitatis Umensis 6                 Umeå
# ...                                                  ...                  ...
# 28990                                 SAU Rapport 2013:9              Uppsala
# 28991                                 SAU Rapport 2013:9              Uppsala
# 29186                        UV Uppsala, Rapport 1996:39              Uppsala
# 29188                        UV Uppsala, Rapport 1996:39              Uppsala
# 30229                                 UV Rapport 2014:22              Mölndal
#
# [325 rows x 38 columns]

# %% [markdown]
# # Author full
#
# In SEAD, tbl_biblio has the column named author whose values seem to be the author followed by the year in parenthesis

# %% [markdown]
# ## Approach
#
# `author` has 2020 distinct raw values with wildly inconsistent formatting: most are already `Surname, Firstname`, some are `Firstname Surname` with no comma at all, several authors get joined with `&` (or plain commas, or the Swedish word `och`), and on top of that there are typos, OCR-looking artifacts, `m fl` ("et al."), `(red)` ("ed."), and nobility particles (`von`, `von der`, ...) scattered around.
#
# Since there are only ~2020 unique strings behind the 30k+ rows, the plan is:
# 1. Parse every unique author string once with a heuristic normalizer that targets the `Surname, N., Surname2, N2. & Surname3, N3.` pattern.
# 2. Flag anything the heuristic can't confidently reorder (rather than silently guessing) so it can be reviewed/corrected by hand.
# 3. Merge the normalized names back onto the full dataframe and append `(year)` to build `author_full`.

# %%
unique_authors = sorted(df['author'].dropna().unique())
len(unique_authors)

# %% [markdown]
# ## Step 1 — Heuristic parser
#
# Rules, in order:
# - Strip trailing `m fl` / `m. fl.` (→ " et al." suffix) and `(red)` (→ " (ed.)" suffix).
# - Replace the Swedish conjunction `och` with `&`.
# - If the string has commas: a single `&` always precedes the last author in this dataset, so replacing `&` with `,` and splitting on commas turns the whole thing into a flat token list. Since every author is written as exactly two tokens (`Surname, Firstname`), pairing tokens two-by-two recovers each author. An odd leftover token is checked once more in case it hides an unseparated `Surname Initial` pair (e.g. `"...,  Wallebom U"`).
# - If the string has commas trailing a nobility particle (`von`, `von der`, `af`, ...) stuck to the wrong side of the pair, move the particle back onto the surname (`"Luft, Magnus von der"` → `"von der Luft, Magnus"`).
# - If the string has **no comma at all**, name order is genuinely ambiguous (`"Firstname Surname"` vs `"Surname Firstname"`) — only two narrow, safe patterns are auto-fixed: a stray `.`/`;`/`:` typo'd in place of a comma (`"Edring. Anders"`), and a bare `Surname Initial` with no punctuation (`"Ebbesen K"`). Anything else with no comma is left untouched and flagged.
# - First names are reduced to a single initial (`"Mattias"` → `"M."`, `"Anna-Karin"` → `"A."`).
# - Anything with digits embedded in the name, or an odd token count that can't be repaired, is flagged `needs_review` and falls back to the original (suffix-stripped) text instead of a guess.

# %%
import re

ET_AL_RE = re.compile(r'[,\s]*\(?\bm\.?\s*f\.?l\.?\)?\.?\s*$', re.I)
RED_RE = re.compile(r'[,\s]*\(?\s*red\.?\s*\)?\.?\s*$', re.I)
PARTICLE_RE = re.compile(r'\b(von|van|af|de)\b', re.I)
DIGIT_RE = re.compile(r'\d')
OCH_RE = re.compile(r'\s+och\s+', re.I)
NAME_WORD = r"[A-ZÅÄÖÜ][\wÀ-ÿ\-']*"
# "Surname. Firstname" / "Surname; Firstname" / "Surname: Firstname" (typo'd comma)
PSEUDO_COMMA_RE = re.compile(rf'^({NAME_WORD})[.;:]\s+({NAME_WORD})$')
# "Surname Initial" with no separator at all, e.g. "Ebbesen K" / "Adamsen Chr."
SHORT_INITIAL_RE = re.compile(rf'^({NAME_WORD})\s+([A-ZÅÄÖÜ][a-zåäöA-ZÅÄÖ]{{0,3}}\.?)$')
PARTICLE_WORDS = {'von', 'van', 'af', 'de', 'der', 'den', 'zu', 'du', 'la', 'le'}


def strip_suffixes(s):
    """Pull off trailing 'm fl' (et al.) / '(red)' (ed.) annotations, in either order."""
    et_al = False
    editor = False
    changed = True
    while changed:
        changed = False
        new_s = ET_AL_RE.sub('', s)
        if new_s != s:
            et_al, s, changed = True, new_s, True
        new_s = RED_RE.sub('', s)
        if new_s != s:
            editor, s, changed = True, new_s, True
    return s.strip(' ,.'), et_al, editor


def fix_particle_order(surname, firstname):
    """Move a trailing nobility particle (e.g. 'Magnus von der') from the firstname
    back onto the surname ('von der Luft'), which is where OCR/data-entry usually lost it."""
    words = firstname.split()
    particles = []
    while words and words[-1].lower() in PARTICLE_WORDS:
        particles.insert(0, words.pop().lower())
    if particles:
        surname = ' '.join(particles) + ' ' + surname
        firstname = ' '.join(words)
    return surname, firstname


def initialize(name_part):
    """Turn a first-name segment into an initial, e.g. 'Mattias' -> 'M.', 'Anna-Karin' -> 'A.'"""
    name_part = name_part.strip(' .')
    if not name_part:
        return ''
    first_word = re.split(r'[\s\-]', name_part)[0]
    return first_word[0].upper() + '.' if first_word else ''


def parse_no_comma_segment(segment):
    """Try to safely split a single no-comma author segment into (surname, firstname).
    Returns None if the order can't be determined with confidence."""
    segment = segment.strip()
    m = PSEUDO_COMMA_RE.match(segment) or SHORT_INITIAL_RE.match(segment)
    return (m.group(1), m.group(2)) if m else None


def build_result(original, formatted, et_al, editor, flags):
    suffix = ''
    if et_al:
        suffix += ' et al.'
    if editor:
        suffix += ' (ed.)'
    formatted_full = (formatted + suffix).strip()
    needs_review = 'needs_review' in flags
    reason = ','.join(sorted(set(f for f in flags if f != 'needs_review')))
    return original, formatted_full, needs_review, reason


def parse_author_string(raw):
    original = raw
    flags = []

    s = OCH_RE.sub(' & ', raw.strip())
    s, et_al, editor = strip_suffixes(s)
    if et_al:
        flags.append('et_al')
    if editor:
        flags.append('editor')
    if DIGIT_RE.search(s):
        flags.append('digits')
    if PARTICLE_RE.search(s):
        flags.append('particle')

    if ',' not in s:
        flags.append('no_comma')
        segments = [seg.strip() for seg in re.split(r'\s*&\s*', s) if seg.strip()]
        parsed_pairs = [parse_no_comma_segment(seg) for seg in segments]
        if all(parsed_pairs):
            authors = [f'{surname}, {initialize(firstname)}'.strip() for surname, firstname in parsed_pairs]
            formatted = authors[0] if len(authors) == 1 else ', '.join(authors[:-1]) + ' & ' + authors[-1]
        else:
            formatted = s  # can't safely determine name order
            flags.append('needs_review')
        return build_result(original, formatted, et_al, editor, flags)

    # a single '&' always precedes the final author in this dataset (verified: no multi-'&' cases)
    s_norm = re.sub(r'\s*&\s*', ', ', s)
    tokens = [t.strip() for t in s_norm.split(',') if t.strip()]

    if len(tokens) % 2 != 0:
        # repair pass: the last token may itself hide an unseparated "Surname Initial" pair
        m = SHORT_INITIAL_RE.match(tokens[-1]) if tokens else None
        if m:
            tokens = tokens[:-1] + [m.group(1), m.group(2)]

    if len(tokens) % 2 != 0:
        flags += ['odd_tokens', 'needs_review']
        return build_result(original, s, et_al, editor, flags)

    authors = []
    for i in range(0, len(tokens), 2):
        surname, firstname = tokens[i], tokens[i + 1]
        if 'particle' in flags:
            surname, firstname = fix_particle_order(surname, firstname)
        initial = initialize(firstname)
        if not initial:
            flags.append('needs_review')
        authors.append(f'{surname}, {initial}'.strip())

    formatted = authors[0] if len(authors) == 1 else ', '.join(authors[:-1]) + ' & ' + authors[-1]
    if 'digits' in flags:
        flags.append('needs_review')

    return build_result(original, formatted, et_al, editor, flags)

# %% [markdown]
# ## Step 2 — Run the parser over every unique value and flag uncertain ones
#
# The result is saved to `output/author_normalization_review.csv` — a lookup table with one row per unique raw `author` value, its parsed form, and whether it needs a human look. Rows flagged `needs_review` fall back to the original (suffix-stripped) text rather than a guessed reordering, so they're easy to spot and hand-correct in the CSV later.

# %%
rows = []
for a in unique_authors:
    original, formatted, needs_review, reason = parse_author_string(a)
    rows.append({'author_raw': original, 'author_parsed': formatted, 'needs_review': needs_review, 'flag_reason': reason})

author_review_df = pd.DataFrame(rows)
author_review_df.to_csv('output/author_normalization_review.csv', index=False, encoding='utf-8-sig')

total = len(author_review_df)
flagged = author_review_df['needs_review'].sum()
print(f'total unique authors: {total}')
print(f'flagged for review: {flagged} ({flagged/total:.1%})')
print()
print(author_review_df.loc[author_review_df['needs_review'], 'flag_reason'].value_counts())

# %% [markdown]
# A peek at what got flagged and why — mostly genuinely ambiguous name order (`no_comma`), malformed comma counts (`odd_tokens`), or garbage/OCR artifacts (`digits`):

# %%
author_review_df[author_review_df['needs_review']].sample(15, random_state=1)[['author_raw', 'author_parsed', 'flag_reason']]

# %% [markdown]
# ## Step 3 — Merge the normalized names back onto `df` and add the year
#
# `author_review_df` is a one-row-per-unique-value lookup, so merging it onto `df` on the `author` column is a clean left join with no row duplication. `author_full` then appends `(publication_year)` — left off entirely when the year is missing rather than producing an empty `()`.

# %%
df_new = df.merge(
    author_review_df[['author_raw', 'author_parsed', 'needs_review']],
    left_on='author', right_on='author_raw', how='left'
).drop(columns='author_raw').rename(columns={'author_parsed': 'author_normalized', 'needs_review': 'author_needs_review'})

df_new['author_full'] = df_new.apply(
    lambda r: f"{r['author_normalized']} ({int(r['publication_year'])})" if pd.notna(r['publication_year']) else r['author_normalized'],
    axis=1
)

print(f"rows flagged for manual author review: {df_new['author_needs_review'].sum()} / {len(df_new)}")
df_new[['author', 'author_normalized', 'author_needs_review', 'publication_year', 'author_full']]

# %% [markdown]
# ## Result
#
# `df_new['author_full']` now holds `Surname, N., Surname2, N2. & Surname3, N3. (year)`, built from ~2020 unique author strings normalized once and mapped back onto all 30,301 rows.
#
# ~4% of rows (`author_needs_review == True`) carry a raw author string the heuristic wasn't confident about (ambiguous `Firstname Surname` order, malformed punctuation, or OCR-looking garbage) — for those, `author_normalized` falls back to the original text. To fix them: edit `author_parsed` in `output/author_normalization_review.csv` for the flagged rows, then re-run the Step 3 merge cell to refresh `df_new`.

# %% [markdown]
# # Unique (material, species) combinations
#
# Extract every distinct `(material, species)` pair present in the data, with how many rows each pair covers.

# %%
material_species = (
    df[['material', 'species']]
    .value_counts(dropna=False)
    .reset_index(name='n_rows')
    .sort_values(['material', 'species'], na_position='first')
    .reset_index(drop=True)
)

print(f'{len(material_species)} unique (material, species) tuples')
material_species
# Out:
# 755 unique (material, species) tuples
#       material                  species  n_rows
# 0          NaN                      NaN       1
# 1    Animalier                Fiskfjäll       1
# 2    Animalier                 Hjorthår       1
# 3    Animalier  Hjärnsubstans, människa       1
# 4    Animalier                      Hår       1
# ..         ...                      ...     ...
# 750  Växtdelar          Örtstam och rot       1
# 751  Växtdelar                Örtstjälk       1
# 752  Växtdelar              Örtstjälkar       1
# 753  Växtdelar                      ört       1
# 754  Växtdelar              örtfragment       1
#
# [755 rows x 3 columns]

# %%
material_species.to_csv('output/strucke_v8_material_species_unique.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# #### Rows with no real information of the site (site_id as the only real information about the site since the column raa_id is often not enough)

# %%
df[df['site_id'].isna()]
# Out:
#          fid     socken  landskap                        village_farm raa_id  \
# 1491    1492      Mosjö     Närke                           Marieberg    NaN
# 1596    1597  Gällivare  Lappland    Kronoöverloppsmark 2:1 Lappviken    NaN
# 1597    1598  Gällivare  Lappland    Kronoöverloppsmark 2:1 Lappviken    NaN
# 1598    1599  Gällivare  Lappland  Kronoöverloppsmark 2:1 Luotosuollo    NaN
# 1599    1600  Gällivare  Lappland  Kronoöverloppsmark 2:1 Luotosuollo    NaN
# ...      ...        ...       ...                                 ...    ...
# 28990  28991    Uppsala   Uppland                         Ulls väg 31    NaN
# 28991  28992    Uppsala   Uppland                        Ulltuna 2:23    NaN
# 29186  29187    Uppsala   Uppland                          Emblas väg    NaN
# 29188  29189    Uppsala   Uppland                      Vattholmavägen    NaN
# 30229  30230       Torp        Bo                          Ström 1:61    NaN
#
#       site_type site_id  uppdragsnummer    lab_no  c14_age_bp  c14_error  \
# 1491        NaN     NaN             NaN   Ua-9615       390.0       70.0
# 1596        NaN     NaN             NaN   ST11446       905.0      190.0
# 1597        NaN     NaN             NaN   ST11448       990.0       70.0
# 1598      Viste     NaN             NaN    ST1851       875.0       65.0
# 1599      Viste     NaN             NaN    ST1852       810.0       65.0
# ...         ...     ...             ...       ...         ...        ...
# 28990   Kokgrop     NaN     201300122.0  Ua-42008      1810.0       30.0
# 28991      Grop     NaN     201300122.0  Ua-42010      3188.0       48.0
# 29186   Boplats     NaN             NaN   Ua-5379      1640.0       60.0
# 29188   Boplats     NaN             NaN   Ua-5381      1390.0       60.0
# 30229    Hägnad     NaN     201400072.0  Ua-31262       937.0       31.0
#
#         d13C  pMC_value  pMC_error c14_data_status  \
# 1491   25.11        NaN        NaN              ok
# 1596   27.40        NaN        NaN              ok
# 1597   27.30        NaN        NaN              ok
# 1598    0.00        NaN        NaN              ok
# 1599    0.00        NaN        NaN              ok
# ...      ...        ...        ...             ...
# 28990  23.40        NaN        NaN              ok
# 28991  28.30        NaN        NaN              ok
# 29186   0.00        NaN        NaN              ok
# 29188   0.00        NaN        NaN              ok
# 30229  26.50        NaN        NaN              ok
#
#                                                  comment assessed_relevant  \
# 1491   Antagligen felaktigt fornlämningsnummer angive...                 J
# 1596                          Saknas i Fornsök Lappviken                 J
# 1597                          Saknas i Fornsök Lappviken                 J
# 1598   Oklart vilken fornlämning och position. Inlämn...                 L
# 1599   Oklart vilken fornlämning och position. Inlämn...                 J
# ...                                                  ...               ...
# 28990          Saknas i Fornsök. Ca 90 m V om L1940:4411                 J
# 28991  Saknas i fornsök belägen ca 27 m NV om L1940:2160                 J
# 29186                Daterar ej grav utan snarare lager.                 J
# 29188                       Oklart läge för anläggningen                 J
# 30229                                           Ej i KMR                 J
#
#             material    species context_id  context_type  northing_3006  \
# 1491          Träkol       Tall        NaN          Grop        6563052
# 1596          Träkol        NaN       A197          Härd        7472534
# 1597          Träkol        NaN       A197          Härd        7472534
# 1598          Träkol        NaN    1375:10          Härd        7472534
# 1599          Träkol        NaN    1375:15  Stensättning        7472534
# ...              ...        ...        ...           ...            ...
# 28990         Träkol         En       A205       Kokgrop        6639689
# 28991         Träkol         Ek      A1147          Grop        6639689
# 29186  Förkolnat frö  Emmervete        NaN         Lager        6639689
# 29188         Träkol        NaN        NaN           NaN        6639689
# 30229            Trä         En        NaN          Påle        6926581
#
#        easting_3006  longitude   latitude location_precision  cal_68_min  \
# 1491         507348  15.128669  59.206488             parish      1628.0
# 1596         720188  20.115143  67.287762             parish      1284.0
# 1597         720188  20.115143  67.287762             parish      1156.0
# 1598         720188  20.115143  67.287762             parish      1254.0
# 1599         720188  20.115143  67.287762             parish      1276.0
# ...             ...        ...        ...                ...         ...
# 28990        647500  17.634433  59.868401             parish       317.0
# 28991        647500  17.634433  59.868401             parish     -1422.0
# 29186        647500  17.634433  59.868401             parish       537.0
# 29188        647500  17.634433  59.868401             parish       770.0
# 30229        562417  16.210221  62.465117             parish      1156.0
#
#        cal_68_max  cal_95_min  cal_95_max  median_cal_year  \
# 1491       1444.0      1645.0      1422.0           1522.0
# 1596        900.0      1407.0       706.0           1106.0
# 1597        994.0      1216.0       896.0           1074.0
# 1598       1048.0      1266.0      1037.0           1165.0
# 1599       1176.0      1298.0      1045.0           1222.0
# ...           ...         ...         ...              ...
# 28990       213.0       336.0       131.0            242.0
# 28991     -1500.0     -1306.0     -1596.0          -1458.0
# 29186       366.0       564.0       255.0            433.0
# 29188       597.0       773.0       561.0            647.0
# 30229      1043.0      1199.0      1030.0           1102.0
#
#                  calibration_method calibration_status  \
# 1491   HPD; IntCal20; rcarbon 1.5.0         calibrated
# 1596   HPD; IntCal20; rcarbon 1.5.0         calibrated
# 1597   HPD; IntCal20; rcarbon 1.5.0         calibrated
# 1598   HPD; IntCal20; rcarbon 1.5.0         calibrated
# 1599   HPD; IntCal20; rcarbon 1.5.0         calibrated
# ...                             ...                ...
# 28990  HPD; IntCal20; rcarbon 1.5.0         calibrated
# 28991  HPD; IntCal20; rcarbon 1.5.0         calibrated
# 29186  HPD; IntCal20; rcarbon 1.5.0         calibrated
# 29188  HPD; IntCal20; rcarbon 1.5.0         calibrated
# 30229  HPD; IntCal20; rcarbon 1.5.0         calibrated
#
#                                   author  publication_year  \
# 1491                    Pettersson, Olof            1998.0
# 1596                    Mulk, Inga-Maria            1994.0
# 1597                    Mulk, Inga-Maria            1994.0
# 1598                    Mulk, Inga-Maria            1994.0
# 1599                    Mulk, Inga-Maria            1994.0
# ...                                  ...               ...
# 28990  Hulth, Helena & Andersson, Fredrk             213.0
# 28991  Hulth, Helena & Andersson, Fredrk             213.0
# 29186             Roslund-Forenius, Ylva            1996.0
# 29188             Roslund-Forenius, Ylva            1996.0
# 30229                   Nordqvist, Bengt            2014.0
#
#                                                    title  \
# 1491           Fjärrvärmeledning mellan Örebro och Kumla
# 1596                                              Sirkas
# 1597                                              Sirkas
# 1598                                              Sirkas
# 1599                                              Sirkas
# ...                                                  ...
# 28990  Förhistoriska utsnitt i Ultuna. Arkeologiska s...
# 28991  Förhistoriska utsnitt i Ultuna. Arkeologiska s...
# 29186                                      Gamla Uppsala
# 29188                                      Gamla Uppsala
# 30229  VA-ledning mellan Henån och Slussen. Arkeologi...
#
#                                                  journal place_of_publication
# 1491   Riksantikvarieämbetet Arkeologiska undersöknin...            Stockholm
# 1596        Studia archaeologica Universitatis Umensis 6                 Umeå
# 1597        Studia archaeologica Universitatis Umensis 6                 Umeå
# 1598        Studia archaeologica Universitatis Umensis 6                 Umeå
# 1599        Studia archaeologica Universitatis Umensis 6                 Umeå
# ...                                                  ...                  ...
# 28990                                 SAU Rapport 2013:9              Uppsala
# 28991                                 SAU Rapport 2013:9              Uppsala
# 29186                        UV Uppsala, Rapport 1996:39              Uppsala
# 29188                        UV Uppsala, Rapport 1996:39              Uppsala
# 30229                                 UV Rapport 2014:22              Mölndal
#
# [338 rows x 38 columns]
