# %% [markdown]
# # EDA for the latest version of Strucke Data
#
# In this notebook the aim is to see the unique values of every row, see if there is anything to be manually resolver or mapped, and understand how much of the data needs cleaning. first a bit of brute force to see all the unique values for every column.

# %%
import pandas as pd

df = pd.read_csv("../data/StruckeC14_Sweden_v1.csv")
print(df.shape)
print('if we drop duplicates')
print(df.drop_duplicates().shape)
df.head()
# Out:
# (30301, 37)
# if we drop duplicates
# (30297, 37)
#      socken  landskap          place_name        raa_id site_type     site_id  \
# 0  Jörlanda  Bohuslän  Kyrkeby 3:34 m.fl.  Jörlanda 158   Boplats  L1969:5267
# 1  Jörlanda  Bohuslän            Berg1:69  Jörlanda 185   Boplats  L1970:9431
# 2  Jörlanda  Bohuslän            Berg1:69  Jörlanda 185   Boplats  L1970:9431
# 3  Jörlanda  Bohuslän            Berg1:69  Jörlanda 185   Boplats  L1970:9431
# 4  Jörlanda  Bohuslän            Berg1:69  Jörlanda 185   Boplats  L1970:9431
#
#   uppdragsnummer    lab_id  c14_age_bp  c14_error  ...  cal_95_min  \
# 0      000103367  Ua-49252      2841.0       33.0  ...      -913.0
# 1            NaN    T-8772      1720.0       80.0  ...       541.0
# 2            NaN    T-8773      2890.0      105.0  ...      -830.0
# 3            NaN    T-8774      2015.0       75.0  ...       207.0
# 4            NaN    T-8775      1990.0       55.0  ...       203.0
#
# ...

# %%
col = "socken"
vc = df[col].value_counts(dropna=False).reset_index().sort_values(by=col)
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# socken: 1055 unique values
#          socken  count
# 216       Abild     35
# 152      Adelsö     53
# 959   Agunnaryd      1
# 372         Ala     15
# 831      Alböke      2
# ..          ...    ...
# 284   Överkalix     25
# 483   Överluleå     10
# 674    Överselö      5
# 799  Övertorneå      3
# 226      Övraby     33
#
# [1055 rows x 2 columns]

# %%
col = "landskap"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# landskap: 36 unique values
#          landskap  count
# 0         Uppland   6042
# 1           Skåne   4780
# 2    Östergötland   3212
# 3    Södermanland   2942
# 4         Halland   1835
# 5        Bohuslän   1773
# 6         Småland   1760
# 7           Närke   1321
# 8   Västergötland   1262
# 9     Västmanland   1247
# 10        Dalarna    669
# 11       Blekinge    563
# 12       Värmland    379
# 13     Norrbotten    328
# 14        Gotland    294
# 15       Lappland    293
# 16       Medelpad    269
# 17          Öland    236
# 18       Jämtland    214
# 19             Bo    173
# 20   Ångermanland    116
# 21     Härjedalen    108
# 22    Hälsingland     88
# 23    Gästrikland     83
# 24             Vg     81
# 25             Ha     79
# 26   Västerbotten     42
# 27             Sm     39
# 28             Sk     18
# 29       Dalsland     16
# 30             Sö     15
# 31             Nä     11
# 32             vg      5
# 33             Vs      3
# ...

# %%
col = "place_name"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# place_name: 5001 unique values
#                place_name  count
# 0        Lockarp 2:1 m fl    223
# 1          Spallationen 1    144
# 2             Rödbobacken    134
# 3              Akalla 4:1    118
# 4     Gamla Uppsala 21:52    115
# ...                   ...    ...
# 4996              Åby 2:1      1
# 4997            Valla 5:1      1
# 4998        Hunnebo 1:647      1
# 4999       Lyttersta 1:43      1
# 5000   Stora Kulltorp 2:2      1
#
# [5001 rows x 2 columns]

# %%
col = "raa_id"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# raa_id: 5439 unique values
#            raa_id  count
# 0             NaN   1841
# 1      Lockarp 18    223
# 2     Skänninge 5    121
# 3        Härad 82    119
# 4     Uppsala 614    107
# ...           ...    ...
# 5434   L2020:4793      1
# 5435          671      1
# 5436    L2018:146      1
# 5437   L2022:7402      1
# 5438    L2023:390      1
#
# [5439 rows x 2 columns]

# %%
col = "site_type"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# site_type: 304 unique values
#                    site_type  count
# 0                    Boplats   8449
# 1              Boplatsområde   6877
# 2    Grav- och boplatsområde   3390
# 3                   Gravfält   1884
# 4                Fossil åker   1059
# ..                       ...    ...
# 299       Gravfält, boplats,      1
# 300                     Grop      1
# 301    Boplatslämnuing övrig      1
# 302                Tegelbruk      1
# 303             Kyrka kapell      1
#
# [304 rows x 2 columns]

# %%
col = "site_id"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# site_id: 6120 unique values
#          site_id  count
# 0            NaN    338
# 1     L1988:4693    223
# 2      L2010:586    120
# 3     L1984:2122    119
# 4     L1941:4268    107
# ...          ...    ...
# 6115  L2020:4793      1
# 6116  L1982:4609      1
# 6117   L2018:146      1
# 6118  L2022:7402      1
# 6119   L2023:390      1
#
# [6120 rows x 2 columns]

# %%
col = "uppdragsnummer"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# uppdragsnummer: 2876 unique values
#      uppdragsnummer  count
# 0               NaN  13050
# 1         201901401    274
# 2         201700787    148
# 3         200800086    101
# 4         200100306    101
# ...             ...    ...
# 2871      202400331      1
# 2872      201400904      1
# 2873      200900594      1
# 2874      202000714      1
# 2875      200800209      1
#
# [2876 rows x 2 columns]

# %%
col = "lab_id"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# lab_id: 30291 unique values
#             lab_id  count
# 0         Ua-86040      3
# 1         Ua-10042      2
# 2         Ua-78697      2
# 3        Ua-26675a      2
# 4         Ua-43186      2
# ...            ...    ...
# 30286     LuS-6339      1
# 30287     16C/0261      1
# 30288  Beta-511943      1
# 30289     Ua-76281      1
# 30290     Ua-76282      1
#
# [30291 rows x 2 columns]

# %%
col = "c14_age_bp"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# c14_age_bp: 4845 unique values
#       c14_age_bp  count
# 0            NaN    345
# 1          250.0    179
# 2         1700.0     98
# 3         1740.0     89
# 4         1690.0     81
# ...          ...    ...
# 4840      8395.0      1
# 4841      2298.0      1
# 4842      2889.0      1
# 4843       909.0      1
# 4844     14575.0      1
#
# [4845 rows x 2 columns]

# %%
col = "c14_error"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# c14_error: 223 unique values
#      c14_error  count
# 0         30.0   5289
# 1         70.0   2155
# 2         40.0   1910
# 3         35.0   1862
# 4         60.0   1689
# ..         ...    ...
# 218      147.0      1
# 219      131.0      1
# 220      112.0      1
# 221      143.0      1
# 222        2.0      1
#
# [223 rows x 2 columns]

# %%
col = "d13C"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# d13C: 730 unique values
#        d13C  count
# 0       NaN  15862
# 1    -25.40    351
# 2    -25.60    344
# 3    -26.10    341
# 4    -26.40    328
# ..      ...    ...
# 725  -30.79      1
# 726  -25.14      1
# 727  -24.78      1
# 728 -224.40      1
# 729  -17.70      1
#
# [730 rows x 2 columns]

# %%
col = "pMC_value"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# pMC_value: 73 unique values
#     pMC_value  count
# 0         NaN  30201
# 1       100.0      5
# 2        99.3      4
# 3       101.6      3
# 4        99.5      3
# ..        ...    ...
# 68      119.9      1
# 69      109.1      1
# 70      104.7      1
# 71      106.9      1
# 72      144.6      1
#
# [73 rows x 2 columns]

# %%
col = "pMC_error"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# pMC_error: 21 unique values
#     pMC_error  count
# 0         NaN  30202
# 1        0.40     29
# 2        0.50     19
# 3        0.80     10
# 4        0.60      8
# 5        0.30      7
# 6        0.70      6
# 7        0.90      5
# 8        1.00      2
# 9        1.60      2
# 10       0.55      1
# 11       0.43      1
# 12      11.00      1
# 13       0.34      1
# 14       1.50      1
# 15       0.52      1
# 16       1.10      1
# 17       0.41      1
# 18       1.20      1
# 19      30.00      1
# 20       0.00      1

# %%
col = "c14_data_status"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# c14_data_status: 4 unique values
#              c14_data_status  count
# 0                         ok  29731
# 1            c14_data_saknas    470
# 2  modern date, no c14 data.     99
# 3     orealistiskt_c14_värde      1

# %%
col = "comment"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# comment: 2058 unique values
#                                                 comment  count
# 0                                                   NaN  26619
# 1                               Daterar ej anläggningen    188
# 2         Viss oklarhet om vilket material som daterats     46
# 3                            14C-ålder saknas i rapport     37
# 4                                      Daterar ej huset     30
# ...                                                 ...    ...
# 2053  14C-ålder saknas i rapport. Kal. 2 sigma 1375-...      1
# 2054  14C-ålder saknas i rapport kal. 2 sigma 1730-1...      1
# 2055   Labnr saknas i rapport Kal. 2 sigma 1680-1515 BC      1
# 2056  14C-ålder saknas i rapport kaol. 2 sigma 1670-...      1
# 2057      14C-ålder saknas i  rapport Kal. 1690-1510 BC      1
#
# [2058 rows x 2 columns]

# %%
col = "assessed_relevant"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# assessed_relevant: 4 unique values
#   assessed_relevant  count
# 0                 J  28364
# 1                 N   1506
# 2                 X    235
# 3               NaN    196

# %%
col = "material"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# material: 42 unique values
#                        material  count
# 0                        träkol  21891
# 1                 förkolnat frö   2667
# 2                  ben, obrända   1245
# 3                   ben, brända   1133
# 4                           trä   1087
# 5                  skalfragment    551
# 6           organisk beläggning    385
# 7                     växtdelar    334
# 8                          bark    302
# 9                         harts    253
# 10                         tand    155
# 11           frö (ej förkolnat)     36
# 12                    animalier     33
# 13                   kol i järn     30
# 14                     karbonat     27
# 15                        humus     24
# 16                        okänd     22
# 17                         horn     21
# 18                         torv     17
# 19                   sotig jord     17
# 20           organiskt material     15
# 21                         bröd      6
# ...

# %%
col = "species"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# species: 544 unique values
#                species  count
# 0                  NaN  12064
# 1                 tall   2929
# 2                björk   1955
# 3                   ek   1736
# 4               hassel   1649
# ..                 ...    ...
# 539     cf. Betula sp.      1
# 540         bark/näver      1
# 541        Populus sp.      1
# 542  Cyperaceae, snöre      1
# 543              haver      1
#
# [544 rows x 2 columns]

# %%
col = "context_id"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# context_id: 10506 unique values
#       context_id  count
# 0            NaN   4266
# 1             A1    718
# 2             A2    462
# 3             A3    333
# 4             A4    258
# ...          ...    ...
# 10501     A50440      1
# 10502     A50526      1
# 10503      A5836      1
# 10504      A5909      1
# 10505      A8793      1
#
# [10506 rows x 2 columns]

# %%
col = "context_type"
vc = df[col].value_counts(dropna=False).reset_index().sort_values(by=col)
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# context_type: 962 unique values
#          context_type  count
# 181   aktivitetslager      9
# 188     aktivitetsyta      8
# 469            ankare      2
# 337        anläggning      3
# 878  annan anläggning      1
# ..                ...    ...
# 304          åkervall      3
# 874           åkeryta      1
# 197         årderspår      7
# 925  östra golvgropen      1
# 7                 NaN    508
#
# [962 rows x 2 columns]

# %%
col = "northing_3006"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# northing_3006: 6173 unique values
#       northing_3006  count
# 0           6157001    223
# 1           6472725    120
# 2           6581472    119
# 3           6642663    107
# 4           6642832    106
# ...             ...    ...
# 6168        6482458      1
# 6169        6538022      1
# 6170        6543544      1
# 6171        6543568      1
# 6172        6543765      1
#
# [6173 rows x 2 columns]

# %%
col = "easting_3006"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# easting_3006: 6149 unique values
#       easting_3006  count
# 0           375846    223
# 1           505067    120
# 2           607657    119
# 3           648609    107
# 4           647453    106
# ...            ...    ...
# 6144        284212      1
# 6145        551529      1
# 6146        564279      1
# 6147        550473      1
# 6148        550513      1
#
# [6149 rows x 2 columns]

# %%
col = "longitude"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# longitude: 6212 unique values
#       longitude  count
# 0     13.032330    223
# 1     15.086680    120
# 2     16.893721    119
# 3     17.656345    107
# 4     17.635827    106
# ...         ...    ...
# 6207  11.303832      1
# 6208  15.896363      1
# 6209  16.119718      1
# 6210  15.879265      1
# 6211  15.880007      1
#
# [6212 rows x 2 columns]

# %%
col = "latitude"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# latitude: 6211 unique values
#        latitude  count
# 0     55.543218    223
# 1     58.395302    120
# 2     59.358220    119
# 3     59.894680    107
# 4     59.896610    106
# ...         ...    ...
# 6206  58.429458      1
# 6207  58.978667      1
# 6208  59.026524      1
# 6209  59.028593      1
# 6210  59.030358      1
#
# [6211 rows x 2 columns]

# %%
col = "location_precision"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# location_precision: 2 unique values
#     location_precision  count
# 0  archaeological site  29963
# 1               parish    338

# %%
col = "cal_68_min"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# cal_68_min: 2837 unique values
#       cal_68_min  count
# 0            NaN    570
# 1         1950.0    542
# 2          773.0    276
# 3          772.0    254
# 4          534.0    176
# ...          ...    ...
# 2832     -7953.0      1
# 2833     -7683.0      1
# 2834     -7362.0      1
# 2835     -7587.0      1
# 2836    -15826.0      1
#
# [2837 rows x 2 columns]

# %%
col = "cal_68_max"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# cal_68_max: 2936 unique values
#       cal_68_max  count
# 0            NaN    570
# 1          775.0    411
# 2          776.0    276
# 3          266.0    224
# 4          435.0    199
# ...          ...    ...
# 2931     -8160.0      1
# 2932     -8226.0      1
# 2933     -7588.0      1
# 2934     -7537.0      1
# 2935    -15989.0      1
#
# [2936 rows x 2 columns]

# %%
col = "cal_95_min"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# cal_95_min: 2810 unique values
#       cal_95_min  count
# 0         1950.0   1020
# 1            NaN    570
# 2          773.0    313
# 3          772.0    171
# 4          402.0    167
# ...          ...    ...
# 2805     -7533.0      1
# 2806     -7600.0      1
# 2807     -7581.0      1
# 2808     -1417.0      1
# 2809    -15616.0      1
#
# [2810 rows x 2 columns]

# %%
col = "cal_95_max"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# cal_95_max: 2904 unique values
#       cal_95_max  count
# 0            NaN    570
# 1          775.0    297
# 2          776.0    280
# 3          434.0    147
# 4          250.0    125
# ...          ...    ...
# 2899     -8545.0      1
# 2900     -8204.0      1
# 2901     -8200.0      1
# 2902     -8254.0      1
# 2903    -16071.0      1
#
# [2904 rows x 2 columns]

# %%
col = "median_cal_year"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# median_cal_year: 5798 unique values
#       median_cal_year  count
# 0                 NaN    570
# 1              1562.0    155
# 2              1347.0    107
# 3              -277.0    106
# 4              -276.0    100
# ...               ...    ...
# 5793          -7644.0      1
# 5794          -1738.0      1
# 5795           -416.0      1
# 5796         -15902.0      1
# 5797          -1546.0      1
#
# [5798 rows x 2 columns]

# %%
col = "calibration_method"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# calibration_method: 2 unique values
#              calibration_method  count
# 0  HPD; IntCal20; rcarbon 1.5.0  29731
# 1                           NaN    570

# %%
col = "calibration_status"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# calibration_status: 3 unique values
#   calibration_status  count
# 0         calibrated  29731
# 1   not calibratable    569
# 2  not yet attempted      1

# %%
col = "author"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# author: 1898 unique values
#                                       author  count
# 0                                  Protokoll    485
# 1                              Strömberg, Bo    277
# 2                          Olausson, Michael    261
# 3                              Carlsson, Tom    208
# 4                             Åstrand, Johan    178
# ...                                      ...    ...
# 1893       Ängeby, Gisela & Nordqvist, Bengt      1
# 1894  Bramstång, Carina & Gustafsson, Agneta      1
# 1895                           Pye, Jonathan      1
# 1896          Vajking, Erik & Swedberg, Stig      1
# 1897  Larsson, G., Sundström, L & Guinard, M      1
#
# [1898 rows x 2 columns]

# %%
col = "publication_year"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# publication_year: 67 unique values
#     publication_year  count
# 0             2006.0   1555
# 1             2014.0   1321
# 2             2005.0   1283
# 3             1996.0   1261
# 4             2017.0   1196
# ..               ...    ...
# 62            1985.0      6
# 63             198.0      4
# 64            1966.0      4
# 65             200.0      4
# 66             201.0      1
#
# [67 rows x 2 columns]

# %%
col = "title"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# title: 4497 unique values
#                                                   title  count
# 0                                       C-14 Dateringar    485
# 1     Järnhantering på boplatser i Halland under äld...    236
# 2     Norra Spånga. Bebyggelse och samhälle under jä...    149
# 3     Östra Odarslöv 13:5, ESS-området Forntid möter...    148
# 4     Det inneslutna rummet-om kultiska hägnader, fo...    145
# ...                                                 ...    ...
# 4492  Tossene 371 och 1042. Tossene socken, Sotenäs ...      1
# 4493  Klippöverhäng och stenåldersboplats vid Åby sä...      1
# 4494  Tossene 137 och 576 inom Valla 4:7 och 5:1, To...      1
# 4495  Tossene L2020:4793 och L2020:4796, Sotenäs kom...      1
# 4496  Stockbåten i Lyttersta. Arkeologisk dokumentat...      1
#
# [4497 rows x 2 columns]

# %%
col = "journal"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# journal: 4299 unique values
#                                                 journal  count
# 0                                               Stencil    546
# 1                                                   NaN    468
# 2         Nya bidrag till Hallands äldsta historia nr 4    236
# 3                          Stockholmsmonografier vol 76    149
# 4                         Arkeologerna, Rapport 2017:11    148
# ...                                                 ...    ...
# 4294                Kulturlandskapet rapporter, 2014:13      1
# 4295                      UV Väst, Internrapport 1993:4      1
# 4296  Rio Kulturkooperativ, Kulturhistoriska rapport...      1
# 4297                Kulturlandskapet rapporter, 2020:14      1
# 4298                                 SAU Rapport 2008:7      1
#
# [4299 rows x 2 columns]

# %%
col = "place_of_publication"
vc = df[col].value_counts(dropna=False).reset_index()
vc.columns = [col, "count"]
print(f"{col}: {len(vc)} unique values")
vc
# Out:
# place_of_publication: 141 unique values
#              place_of_publication  count
# 0                       Stockholm   6400
# 1                         Uppsala   3106
# 2                            Lund   2814
# 3                       Linköping   2553
# 4                        Västerås   1314
# ..                            ...    ...
# 136                         Örero      1
# 137                    Skellefteå      1
# 138                      Arjeplog      1
# 139  Uppsala. Rapport 2: Uppsala.      1
# 140                     Västeråsd      1
#
# [141 rows x 2 columns]

# %% [markdown]
# ### Look for rows with more than one site_id in the value

# %%
df.loc[df['site_id'].str.contains(',')]
# Out:
#                 socken landskap            place_name  \
# 337              Vedby    Skåne              Linneröd
# 1016          Odensala  Uppland               Åslunda
# 1017          Odensala  Uppland               Åslunda
# 1018          Odensala  Uppland               Åslunda
# 1019          Odensala  Uppland               Åslunda
# ...                ...      ...                   ...
# 26390  Stora Herrestad    Skåne  Herrestad 68:88 m fl
# 26391  Stora Herrestad    Skåne  Herrestad 68:88 m fl
# 26392  Stora Herrestad    Skåne  Herrestad 68:88 m fl
# 26393  Stora Herrestad    Skåne  Herrestad 68:88 m fl
# 26394  Stora Herrestad    Skåne  Herrestad 68:88 m fl
#
#                            raa_id                     site_type  \
# 337                Vedby 92 (110)  Bytomt/gårdstomt, Blästplats
# 1016                 Odensala 402                       Boplats
# 1017                 Odensala 402                       Boplats
# ...

# %% [markdown]
# ### Extract unique `landskap` values for a manual resolution to be created
#
# A handful of `landskap` values are abbreviations/typos of a full province name already present
# elsewhere in the column (e.g. `Bo` vs `Bohuslän`, `Vg`/`vg` vs `Västergötland`, `Sk` vs `Skåne`).
# Export the raw value counts as the starting point for a hand-curated
# `landskap_manual_resolution.csv`, same pattern as `material_manual_resolution.csv`'s origin in
# `archive/notebooks/material_counts.ipynb`.

# %%
from pathlib import Path

landskap_counts = df['landskap'].value_counts(dropna=False).reset_index()
landskap_counts.columns = ['landskap', 'count']
print(f'{len(landskap_counts)} unique landskap values')

OUTPUT_DIR = Path('../output/landskap')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
landskap_counts.to_csv(OUTPUT_DIR / 'landskap_counts.csv', index=False)

landskap_counts
# Out:
# 36 unique landskap values
#          landskap  count
# 0         Uppland   6042
# 1           Skåne   4780
# 2    Östergötland   3212
# 3    Södermanland   2942
# 4         Halland   1835
# 5        Bohuslän   1773
# 6         Småland   1760
# 7           Närke   1321
# 8   Västergötland   1262
# 9     Västmanland   1247
# 10        Dalarna    669
# 11       Blekinge    563
# 12       Värmland    379
# 13     Norrbotten    328
# 14        Gotland    294
# 15       Lappland    293
# 16       Medelpad    269
# 17          Öland    236
# 18       Jämtland    214
# 19             Bo    173
# 20   Ångermanland    116
# 21     Härjedalen    108
# 22    Hälsingland     88
# 23    Gästrikland     83
# 24             Vg     81
# 25             Ha     79
# 26   Västerbotten     42
# 27             Sm     39
# 28             Sk     18
# 29       Dalsland     16
# 30             Sö     15
# 31             Nä     11
# 32             vg      5
# 33             Vs      3
# 34             Up      3
# ...

# %% [markdown]
# Let's check for information in the rows for those values to be resolved.

# %%
df[df['landskap'].isin(['Bo', 'Ha', 'Nä', 'Ög', 'Sk', 'Sm', 'Sö', 'Up', 'Vg', 'vg', 'Vs'])]
# Out:
#                 socken landskap          place_name      raa_id  \
# 29859    Arboga socken       Vs         Jäder 1: 15          65
# 29860    Arboga socken       Vs         Jäder 1: 15          65
# 29861         Aringsås       Sm   Spåningslanda 4:3         185
# 29862         Aringsås       Sm   Spåningslanda 4:3         186
# 29863         Aringsås       Sm       Aringsås 15:1          59
# ...                ...      ...                 ...         ...
# 30296  Västra Vingåker       Sö    Sävstaholm 2:325          79
# 30297  Västra Vingåker       Sö  Stora Kulltorp 2:2   L2018:146
# 30298  Västra Vingåker       Sö    Sävstaholm 2:382  L2022:7402
# 30299  Västra Vingåker       Sö    Sävstaholm 2:382   L2023:390
# 30300    Arboga socken       Vs         Jäder 1: 15          65
#
#                   site_type     site_id uppdragsnummer       lab_id  \
# 29859          Stensättning  L2002:5029      000102567     Ua-10042
# ...

# %%
# there seems to be an error for similar title and different socken and landskap
error_df = df[df['title']=='Arkeologisk förundersökning. Fossil åker Aringsås 77:1. Aringsås socken i Alvesta kommun, Kronobergs län']
error_df
# Out:
#          socken landskap         place_name raa_id           site_type  \
# 29861  Aringsås       Sm  Spåningslanda 4:3    185  Kolningsanläggning
# 29862  Aringsås       Sm  Spåningslanda 4:3    186                Härd
# 29865  Aringsås       Sm  Spåningslanda 4:3     77         Fossil åker
# 29866  Aringsås       Sm  Spåningslanda 4:3     77         Fossil åker
# 29867  Aringsås       Sm  Spåningslanda 4:3     77         Fossil åker
# 29868  Aringsås       Sm  Spåningslanda 4:3     77         Fossil åker
# 29869  Aringsås       Sm  Spåningslanda 4:3     77         Fossil åker
# 29870  Aringsås       Sm  Spåningslanda 4:3     77         Fossil åker
# 29871  Aringsås       Sm  Spåningslanda 4:3     77         Fossil åker
# 29872  Aringsås       Sm  Spåningslanda 4:3     77         Fossil åker
# 29879    Bogsta       Sö           Ekla 1:5     78             Boplats
#
#           site_id uppdragsnummer    lab_id  c14_age_bp  c14_error  ...  \
# ...

# %%
df.iloc[29872:29882].to_excel('../output/socken_landskap_title_question.xlsx') 
error_df.to_excel('../output/Aringsås_study_mistake.xlsx')

# %% [markdown]
# We could also assume that they are abbreviations and infer what landskap they are refering to, but for the particular case of Vs that could refer to Västerbotten, Västmanland and Västergötland, it is better to take the time to check this before assumming correct resolutions.
# - Vs -> Västmanland
# - Sm -> Småland
# - Bo -> Bohuslän
# -

# %% [markdown]
# ### Extract `lab_id` prefixes and match against `tbl_dating_labs`
#
# Same approach as the `lab_no` matching done in `archive/notebooks/explore.ipynb` for
# `c14_master_v08.xlsx`, adapted to this dataset's `lab_id` column. The *prefix* of `lab_id`
# (the letters before the dash/number, e.g. `Ua` in `Ua-49252`) should correspond to a lab's
# `international_lab_id` in `tbl_dating_labs`. We keep the full `lab_id` string as-is, but use
# the prefix to resolve each row to a SEAD `dating_lab_id`. The end of this section exports a
# full prefix-to-lab mapping for manual review, since not every value can be resolved
# automatically.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('../..').resolve()))
from shared.resolution import common

# .env lives at the true repo root, two levels up from current/notebooks/.
engine = common.get_db_engine('../../.env')

dating_labs = pd.read_sql(
    "select dating_lab_id, international_lab_id, lab_name from public.tbl_dating_labs",
    engine,
)
print(f"{len(dating_labs)} labs in sead_staging")
dating_labs.head()
# Out:
# 234 labs in sead_staging
#    dating_lab_id international_lab_id  \
# 0            685                    A
# 1            686                   AA
# 2            687                  AAR
# 3            688                   AC
# 4            689                 AECV
#
#                                      lab_name
# 0                                     Arizona
# 1                                         NSF
# 2                        University of Aarhus
# 3                                      Ingeis
# 4  Alberta Environmental Center of Vegreville

# %% [markdown]
# #### Extracting the prefix
#
# Not every `lab_id` follows the `<prefix>-<number>` pattern, so the parser below sorts every
# row into one of three categories instead of silently dropping the awkward ones:
#
# - **`standard`** -- a normal `<letters><separator><number>` value, e.g. `Ua-49252`. A handful
#   of these spell out `Okänd` (Swedish for "unknown") in place of the accession number, e.g.
#   `Ua-Okänd62` or `ICA-Okänd 2` -- the lab is still known, only the specific sample number is
#   missing, so `Okänd<number>` is stripped out before reading the prefix.
# - **`unknown_no_lab`** -- `lab_id` is literally just `Okänd ###` with no lab code at all -- a
#   genuinely unknown lab.
# - **`non_standard_id`** -- ids like `17C/0902` or `14C-5261` that don't start with a letter at
#   all. These look like an internal accession scheme (year + a 1-2 letter sample-type code +
#   sequence number), not an international lab code, so no lab can be derived from them.

# %%
import re

def lab_id_prefix(lab_id):
    s = str(lab_id)
    # "Okänd<number>" means the *sample number* is unknown, not the lab -- drop it before
    # reading the prefix, e.g. "Ua-Okänd62" -> "Ua"
    core = re.sub(r"[-\s]?[Oo]k[äa]nd\s*\d*", "", s)
    leading = re.match(r"^[A-Za-z]+", core)
    if leading:
        return leading.group(0), "standard"
    if core.strip() == "":
        return "(Okänd -- no lab given at all)", "unknown_no_lab"
    # no leading letter, but there might be one buried in there (e.g. the "C" in "17C/0902")
    embedded = re.search(r"[A-Za-z]+", core)
    tag = embedded.group(0) if embedded else "?"
    return f"~{tag} (embedded, not a leading prefix)", "non_standard_id"

parsed = df["lab_id"].apply(lab_id_prefix)
df["lab_id_prefix"] = parsed.apply(lambda t: t[0])
df["lab_id_prefix_category"] = parsed.apply(lambda t: t[1])
df["lab_id_prefix_category"].value_counts()
# Out:
# lab_id_prefix_category
# standard           29640
# non_standard_id      576
# unknown_no_lab        85
# Name: count, dtype: int64

# %% [markdown]
# #### Matching prefixes against `international_lab_id`
#
# Only `standard`-category prefixes are matchable at all. `international_lab_id` isn't
# consistently cased against this dataset, and some codes carry a trailing `*` (the
# *Radiocarbon* journal convention for a lab that's no longer active) that this dataset never
# has. Match in three tiers -- exact, case-insensitive, and case-insensitive with the trailing
# `*` stripped -- and record which tier each prefix matched on, so low-confidence matches stay
# visible instead of being silently accepted.

# %%
exact = dict(zip(dating_labs["international_lab_id"], dating_labs["dating_lab_id"]))
by_lower = {code.lower(): (code, lab_id) for code, lab_id in exact.items()}
by_lower_stripped = {code.rstrip("*").lower(): (code, lab_id) for code, lab_id in exact.items()}

def match_lab(prefix, category):
    if category != "standard":
        return pd.Series([None, None, None])
    if prefix in exact:
        return pd.Series([exact[prefix], prefix, "exact"])
    hit = by_lower.get(prefix.lower())
    if hit:
        return pd.Series([hit[1], hit[0], "case_insensitive"])
    hit = by_lower_stripped.get(prefix.rstrip("*").lower())
    if hit:
        return pd.Series([hit[1], hit[0], "stripped_star"])
    return pd.Series([None, None, None])

prefix_matches = (
    df.groupby(["lab_id_prefix", "lab_id_prefix_category"])
    .agg(n_rows=("lab_id", "size"),
         example_lab_id=("lab_id", lambda s: "; ".join(sorted(s.astype(str).unique())[:3])))
    .reset_index()
)
prefix_matches[["dating_lab_id", "matched_international_lab_id", "match_type"]] = prefix_matches.apply(
    lambda r: match_lab(r["lab_id_prefix"], r["lab_id_prefix_category"]), axis=1,
)
lab_name_by_id = dict(zip(dating_labs["dating_lab_id"], dating_labs["lab_name"]))
prefix_matches["matched_lab_name"] = prefix_matches["dating_lab_id"].map(lab_name_by_id)
prefix_matches = prefix_matches.sort_values("n_rows", ascending=False).reset_index(drop=True)
prefix_matches
# Out:
#                            lab_id_prefix lab_id_prefix_category  n_rows  \
# 0                                     Ua               standard   19691
# 1                                     ST               standard    3622
# 2                                   Beta               standard    2954
# 3                                    Poz               standard     749
# 4                                     Lu               standard     492
# 5    ~C (embedded, not a leading prefix)        non_standard_id     488
# 6                                    GrN               standard     367
# 7                                    LuS               standard     357
# 8                                    LTL               standard     308
# 9                                    LuA               standard     198
# 10                                     T               standard     160
# 11                                     U               standard     132
# ...

# %%
matched_mask = prefix_matches["dating_lab_id"].notna()
by_type = prefix_matches.groupby("match_type", dropna=False)["n_rows"].sum().sort_values(ascending=False)
total_matched = prefix_matches.loc[matched_mask, "n_rows"].sum()
print(f"{total_matched} / {len(df)} rows ({total_matched / len(df):.1%}) resolve to a SEAD dating_lab_id")
print()
print("rows by match_type (NaN = unresolved):")
print(by_type)
print()
print("prefixes with a real-looking lab code but no match in tbl_dating_labs (candidates to add to SEAD):")
prefix_matches[prefix_matches["lab_id_prefix"].notna() & ~matched_mask].sort_values("n_rows", ascending=False)
# Out:
# 28979 / 30301 rows (95.6%) resolve to a SEAD dating_lab_id
#
# rows by match_type (NaN = unresolved):
# match_type
# exact               24977
# stripped_star        3622
# NaN                  1322
# case_insensitive      380
# Name: n_rows, dtype: int64
#
# prefixes with a real-looking lab code but no match in tbl_dating_labs (candidates to add to SEAD):
#                            lab_id_prefix lab_id_prefix_category  n_rows  \
# 5    ~C (embedded, not a leading prefix)        non_standard_id     488
# 8                                    LTL               standard     308
# 9                                    LuA               standard     198
# 14        (Okänd -- no lab given at all)         unknown_no_lab      85
# 15                                 UGAMS               standard      72
# 19   ~P (embedded, not a leading prefix)        non_standard_id      42
# 20                                  MAMS               standard      28
# ...

# %% [markdown]
# #### Possible-match suggestions and a full export for manual review
#
# For every unresolved `standard` prefix, suggest the closest `international_lab_id` values
# (via string similarity) as hints -- not auto-applied, just a head start for whoever reviews
# this. Then export **one row per unique prefix/category** -- including the `non_standard_id`
# and `unknown_no_lab` buckets -- as the full mapping from every `lab_id` value in the dataset
# to a `dating_lab_id`, with a blank `manual_dating_lab_id` column to fill in after review, same
# pattern as `landskap_counts.csv`'s export above.

# %%
import difflib

all_codes = dating_labs["international_lab_id"].tolist()
unknown_lab_id = dating_labs.loc[dating_labs["international_lab_id"] == "Unknown", "dating_lab_id"].iloc[0]

def suggest_matches(row):
    if row["lab_id_prefix_category"] != "standard" or pd.notna(row["dating_lab_id"]):
        return ""
    close = difflib.get_close_matches(row["lab_id_prefix"], all_codes, n=3, cutoff=0.6)
    return "; ".join(f"{c} (dating_lab_id={exact[c]}, {lab_name_by_id[exact[c]]})" for c in close)

review = prefix_matches.copy()
review["possible_match_suggestions"] = review.apply(suggest_matches, axis=1)

review.loc[review["lab_id_prefix_category"] == "unknown_no_lab",
           ["dating_lab_id", "matched_international_lab_id", "matched_lab_name", "match_type"]] = [
    unknown_lab_id, "Unknown", lab_name_by_id[unknown_lab_id], "unknown_placeholder",
]

review["needs_review"] = (
    review["match_type"].isin(["stripped_star", "unknown_placeholder"]) | review["match_type"].isna()
)
review["manual_dating_lab_id"] = pd.NA

notes = pd.Series("", index=review.index)
notes[review["lab_id_prefix_category"] == "non_standard_id"] = (
    "lab_id doesn't follow <prefix>-<number>; the embedded letter is a sample-type code, not "
    "an international lab code -- needs manual research to identify the lab"
)
notes[review["lab_id_prefix_category"] == "unknown_no_lab"] = (
    "lab_id literally says 'Okänd' with no lab code -- pre-filled with SEAD's generic 'Unknown' "
    "lab; override manual_dating_lab_id if the real lab can be identified"
)
notes[review["match_type"] == "stripped_star"] = (
    "only matches after stripping the DB's trailing '*' and ignoring case -- confirm before trusting it"
)
review["notes"] = notes

review = review[[
    "lab_id_prefix", "lab_id_prefix_category", "n_rows", "example_lab_id", "match_type",
    "dating_lab_id", "matched_international_lab_id", "matched_lab_name",
    "possible_match_suggestions", "needs_review", "manual_dating_lab_id", "notes",
]]

OUTPUT_DIR = Path('../output/lab_id')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
review.to_csv(OUTPUT_DIR / 'lab_id_prefix_matches.csv', index=False)
review.to_excel(OUTPUT_DIR / 'lab_id_prefix_matches.xlsx', index=False)
print(f"wrote {OUTPUT_DIR}/lab_id_prefix_matches.csv and .xlsx: {len(review)} prefixes covering "
      f"{review['n_rows'].sum()} rows, {review['needs_review'].sum()} flagged for manual review")
review
# Out:
# wrote ..\output\lab_id/lab_id_prefix_matches.csv and .xlsx: 50 prefixes covering 30301 rows, 20 flagged for manual review
#                            lab_id_prefix lab_id_prefix_category  n_rows  \
# 0                                     Ua               standard   19691
# 1                                     ST               standard    3622
# 2                                   Beta               standard    2954
# 3                                    Poz               standard     749
# 4                                     Lu               standard     492
# 5    ~C (embedded, not a leading prefix)        non_standard_id     488
# 6                                    GrN               standard     367
# 7                                    LuS               standard     357
# 8                                    LTL               standard     308
# 9                                    LuA               standard     198
# ...

# %% [markdown]
# #### Assigning `dating_lab_id`
#
# Join the per-prefix matches back onto every row. `unknown_no_lab` rows get SEAD's generic
# `Unknown` lab by default; everything else stays `NaN` until resolved via the exported CSV
# above. `dating_lab_match_type` travels along so low-confidence and unresolved rows stay easy
# to filter out downstream if a stricter cut is wanted before ingestion.

# %%
df = df.merge(
    prefix_matches[["lab_id_prefix", "lab_id_prefix_category", "dating_lab_id", "match_type"]].rename(
        columns={"match_type": "dating_lab_match_type"}
    ),
    on=["lab_id_prefix", "lab_id_prefix_category"], how="left",
)
df.loc[df["lab_id_prefix_category"] == "unknown_no_lab", ["dating_lab_id", "dating_lab_match_type"]] = [
    unknown_lab_id, "unknown_placeholder",
]
print(f'{df["dating_lab_id"].notna().sum()} / {len(df)} rows have a dating_lab_id')
df[["lab_id", "lab_id_prefix", "lab_id_prefix_category", "dating_lab_id", "dating_lab_match_type"]].sample(10, random_state=1)
# Out:
# 29064 / 30301 rows have a dating_lab_id
#          lab_id lab_id_prefix lab_id_prefix_category  dating_lab_id  \
# 5766   Ua-39061            Ua               standard          882.0
# 15927  Ua-15810            Ua               standard          882.0
# 2757   Ua-42292            Ua               standard          882.0
# 17767  Ua-13733            Ua               standard          882.0
# 20414    ST4728            ST               standard          864.0
# 14091  Ua-28887            Ua               standard          882.0
# 18896  Ua-52373            Ua               standard          882.0
# 26616    Lu-454            Lu               standard          791.0
# 16763  Ua-39103            Ua               standard          882.0
# 10931  Ua-62766            Ua               standard          882.0
#
#       dating_lab_match_type
# 5766                  exact
# 15927                 exact
# 2757                  exact
# 17767                 exact
# 20414         stripped_star
# ...

# %% [markdown]
# Looking for groupings by title, possible sample_group definitions

# %%
df.groupby(['title'], as_index=False).count()
# Out:
#                                                   title  socken  landskap  \
# 0      Arkeologisk förundersökning i Sölve 2018 Sölv...       2         2
# 1       "Kullen"-en gravplats i sydvästligaste Småland.       7         7
# 2                           "Kyrkogården" på Norsholmen       1         1
# 3     "Viste från järnåldern". Tillfälligt utnyttjad...       5         5
# 4     "att den är urgammal och förmodligen kan räkna...       3         3
# ...                                                 ...     ...       ...
# 4491  ”Af detta synes framgå, att Wästerås varit en ...       4         4
# 4492  ”Flacka stensättningar och en handfull brända ...      13        13
# 4493  ”Man kan nu intet weta at berätta, enär denne ...       2         2
# 4494  ”Spelehögen” – en stor gravhög från romersk jä...       5         5
# 4495  ”Västerås är en ganska stor och vacker uppstad,…”       2         2
#
#       place_name  raa_id  site_type  site_id  uppdragsnummer  lab_id  \
# ...

# %%
df.groupby(['title', 'site_id'], as_index=False).nunique()
# Out:
#                                                   title     site_id  socken  \
# 0      Arkeologisk förundersökning i Sölve 2018 Sölv...  L1978:9934       1
# 1       "Kullen"-en gravplats i sydvästligaste Småland.  L1952:3609       1
# 2                           "Kyrkogården" på Norsholmen   L1977:308       1
# 3     "Viste från järnåldern". Tillfälligt utnyttjad...   L1969:707       1
# 4     "att den är urgammal och förmodligen kan räkna...   L2002:434       1
# ...                                                 ...         ...     ...
# 7625  ”Flacka stensättningar och en handfull brända ...   L1969:510       1
# 7626  ”Flacka stensättningar och en handfull brända ...   L1990:114       1
# 7627  ”Man kan nu intet weta at berätta, enär denne ...   L2002:434       1
# 7628  ”Spelehögen” – en stor gravhög från romersk jä...   L1969:510       1
# 7629  ”Västerås är en ganska stor och vacker uppstad,…”   L2002:434       1
#
# ...

# %%
# two place names, one lämningsnummer
df[df['site_id']=='L2022:77']
# Out:
#             socken landskap  place_name raa_id             site_type  \
# 4572  Biskopskulla  Uppland   Rönna 2:7    NaN  Boplatslämning övrig
# 4573  Biskopskulla  Uppland  Gissle 1:4    NaN  Boplatslämning övrig
#
#        site_id uppdragsnummer    lab_id  c14_age_bp  c14_error  ...  \
# 4572  L2022:77      202100448  Ua-72112      2311.0       27.0  ...
# 4573  L2022:77      202100448  Ua-72111      2799.0       28.0  ...
#
#       calibration_status            author  publication_year  \
# 4572          calibrated  Stenström, Karin            2022.0
# 4573          calibrated  Stenström, Karin            2022.0
#
#                                                   title  \
# 4572  Arkeologi för fiber i Biskopskulla med omnejd....
# 4573  Arkeologi för fiber i Biskopskulla med omnejd....
#
#                                  journal place_of_publication lab_id_prefix  \
# 4572  Upplandsmuseets rapporter, 2022:02              Uppsala            Ua
# ...

# %%
df[df['lab_id'].duplicated(keep=False)].sort_values('lab_id')
# Out:
#                 socken  landskap                     place_name      raa_id  \
# 30295  Västra Vingåker        Sö               Sävstaholm 2:325          79
# 30296  Västra Vingåker        Sö               Sävstaholm 2:325          79
# 30283          Tossene        Bo                      Torp 1:13         572
# 30282          Tossene        Bo                      Torp 1:13         572
# 29859    Arboga socken        Vs                    Jäder 1: 15          65
# 30300    Arboga socken        Vs                    Jäder 1: 15          65
# 29969          Hanhals        Ha                 Hammargård 1:7         121
# 29968          Hanhals        Ha                 Hammargård 1:7         121
# 29982           Hyssna        Vg                  Brandskog 1:5         224
# 29981           Hyssna        Vg                  Brandskog 1:5         224
# 30208            Stala        Bo  Lundby 1:8, 1:10, Varekil 2:1  Stala 27:1
# ...

# %%
dup_lab_id_df = df[df['lab_id'].duplicated(keep=False)]
other_cols = [c for c in df.columns if c != 'lab_id']
nunique_per_group = dup_lab_id_df.groupby('lab_id')[other_cols].nunique(dropna=False)

constant_cols = [c for c in other_cols if (nunique_per_group[c] <= 1).all()]
varying_cols = [c for c in other_cols if c not in constant_cols]

print(f'{len(constant_cols)} columns identical across every duplicated lab_id group:')
print(constant_cols)
print()
print(f'{len(varying_cols)} columns differ within at least one group:')
varying_cols
# Out:
# 31 columns identical across every duplicated lab_id group:
# ['socken', 'landskap', 'place_name', 'site_type', 'uppdragsnummer', 'c14_age_bp', 'c14_error', 'd13C', 'pMC_value', 'pMC_error', 'c14_data_status', 'comment', 'assessed_relevant', 'material', 'location_precision', 'cal_68_min', 'cal_68_max', 'cal_95_min', 'cal_95_max', 'median_cal_year', 'calibration_method', 'calibration_status', 'author', 'publication_year', 'title', 'journal', 'place_of_publication', 'lab_id_prefix', 'lab_id_prefix_category', 'dating_lab_id', 'dating_lab_match_type']
#
# 9 columns differ within at least one group:
# ['raa_id',
#  'site_id',
#  'species',
#  'context_id',
#  'context_type',
#  'northing_3006',
#  'easting_3006',
#  'longitude',
#  'latitude']

# %%
dup_lab_id_df[['lab_id'] + varying_cols].sort_values('lab_id').drop_duplicates()
# Out:
#           lab_id      raa_id     site_id   species context_id  \
# 30295  16CB/0263          79  L1983:6225  människa         A8
# 30283  Poz-18945         572  L1967:6919      korn      A2888
# 30282  Poz-18945         572  L1967:6919      korn       A760
# 29859   Ua-10042          65  L2002:5029       NaN        A14
# 29969  Ua-26675a         121  L1997:4829       NaN       A192
# 29968  Ua-26675a         121  L1997:4829        al       A192
# 29982   Ua-43186         224  L1960:8392     björk      A1010
# 30208   Ua-63162  Stala 27:1  L1968:8125    hassel      A2005
# 29951   Ua-78697   L2024:541   L2024:541      tall        A10
# 29950   Ua-78697   L2024:541   L2024:541        ek        A10
# 30033   Ua-81376         372  L1959:3149        al        A36
# 30034   Ua-81376         373  L1959:3188        al        A36
# 30232   Ua-86040  L2023:7974  L2023:7974     björk        A55
# 30233   Ua-86040  L2023:7974  L2023:7974     björk       A264
# ...

# %% [markdown]
# from here we can conclude that there are some rows duplicated. and apart from that, those that share a lab_id, get differenciated by the context_id. So, at leat for analysis entities we needone per (lab_id, context_id) pair (equal to number of rows)

# %% [markdown]
# ## Tasks To Be Done
#
# ### Pre-ShapeShifter
#
# - split `site_id` by commas, rename columns to avoid `_id`. **DONE**
# - manual map of the unusable values of `landskap`. **DONE**
# - split `uppdragsnummer` by commas. **DONE**
# - Extract lab prefixes from `lab_id` in a new column. **DONE**
# - Standarize lab prefixes according to lab pdf or SEAD's. **DONE for matches against `tbl_dating_labs`; unresolved prefixes still need `lab_id_prefix_matches.csv` filled in by hand**
# - Add lab prefix and name to the modified output **DONE**
#
# **To be asked:**
# 1. Possible split in the `context_type` for adjectives in a similar feature (see df printed for context_type: "stensättning" appears multiple times with different descriptions like "oval", "rund", "avlång", etc.)
# 2. translate `context_type` values (they are in swedish and `tbl_feature_types.feature_type_name` is in english)
# 3. What are the sampling groups to be considered (by study?)
# ### In ShapeShifter
#
# - Create a column from northing_3006 and easting_3006 with values like f'({str(northing_3006)}, {str(easting_3006)})'
# - Create full reference **DONE**
# - Create dataset
#
# **To be asked:**
#
# 1. How to handle `lab_id` being almost unique to every row. Should we create a dataset for every one of those?
# 2. How to create the dataset, sample groups, physical samples, analysis entities, etc.
#   -> from my understanding, as analysis_entity would require dataset_id and physical_sample_id, we would need first to create those entities, and for physical_sample one needs a sample_group_id defined, so there is some entities that require their parents to be created first, therefore one needs to define those first. Sample group names and dataset names to be defined

# %% [markdown]
# ## Finding candidates for `sample_group_name`, `sample_name`, and `dataset_name`
#
# SEAD's physical_sample/sample_group/dataset hierarchy needs names, but this dataset carries no
# explicit sample_group/dataset field to reuse - the exploration below looks for a real-world
# grouping key already present in the data that could serve as one. Starting point: unique
# (`place_name`, `site_id`) pairs (`site_id` is renamed `lamningsnummer` in the pipeline), then
# check which `place_name` values are attached to more than one distinct `site_id`.

# %%
place_lamningsnummer_pairs = df[['place_name', 'site_id']].drop_duplicates()
print(f'{len(place_lamningsnummer_pairs)} unique (place_name, site_id) pairs out of {len(df)} rows')
place_lamningsnummer_pairs
# Out:
# 6653 unique (place_name, site_id) pairs out of 30301 rows
#                place_name     site_id
# 0      Kyrkeby 3:34 m.fl.  L1969:5267
# 1                Berg1:69  L1970:9431
# 7      Jörlanda-Berg 1:66  L1970:9914
# 10            Bråland 2:7    L1969:38
# 11          Kollekärr 1:1    L1969:99
# ...                   ...         ...
# 30293      Lyttersta 1:43  L1982:4609
# 30294    Sävstaholm 2:325  L1983:6225
# 30297  Stora Kulltorp 2:2   L2018:146
# 30298    Sävstaholm 2:382  L2022:7402
# 30299    Sävstaholm 2:382   L2023:390
#
# [6653 rows x 2 columns]

# %% [markdown]
# ### `place_name` values repeated across more than one `site_id`

# %%
place_name_site_id_counts = place_lamningsnummer_pairs.groupby('place_name')['site_id'].nunique(dropna=False)
repeated_place_names = place_name_site_id_counts[place_name_site_id_counts > 1].sort_values(ascending=False)
print(f'{len(repeated_place_names)} place_name values paired with more than one distinct site_id')
repeated_place_names
# Out:
# 914 place_name values paired with more than one distinct site_id
# place_name
# Molnby 1:6                  18
# Bäckeby 2:2                 13
# Råberga                     12
# Norrby 1:1                  12
# Fyllinge 20:393             11
#                             ..
# Antorp 1:2                   2
# Apalle 3:15                  2
# Arlandastad, Norslunda       2
# Alby 3:3                     2
# Alby 19:1, Kalvsvik 16:1     2
# Name: site_id, Length: 914, dtype: int64

# %%
place_lamningsnummer_pairs_with_title = df[['place_name', 'site_id', 'title']].drop_duplicates()
place_lamningsnummer_pairs_with_title[
    place_lamningsnummer_pairs_with_title['place_name'].isin(repeated_place_names.index)
].sort_values(['place_name', 'site_id'])
# Out:
#                    place_name     site_id  \
# 19466   Halla-Väsby 4:1 m.fl.  L2022:4177
# 19467   Halla-Väsby 4:1 m.fl.  L2022:4185
# 8767          Aareavaara 4:10   L1992:814
# 8761          Aareavaara 4:10  L1992:9189
# 8777          Aareavaara 4:10  L1992:9189
# ...                       ...         ...
# 6762       Övra Glumslöv 37:4  L1988:3061
# 6778       Övra Glumslöv 37:4  L1988:3061
# 10032         Övre Heden 7:64   L1998:105
# 10033         Övre Heden 7:64   L1998:106
# 10017         Övre Heden 7:64  L1999:5404
#
#                                                    title
# 19466  Fiber i Halla. Arkeologisk undersökning i form...
# 19467  Fiber i Halla. Arkeologisk undersökning i form...
# 8767                                     C-14 Dateringar
# 8761   Aarevaara - Tidigmesolitiskakustboplatser nära...
# 8777   Allmän arkeologisk utredning. Tapuli. Utrednin...
# ...                                                  ...
# ...

# %%
df[df['place_name'] == 'Övra Glumslöv 37:4']
# Out:
#         socken landskap          place_name        raa_id      site_type  \
# 6756  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6757  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6758  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6759  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6760  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6761  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6762  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6763  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6764  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6765  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6766  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# 6767  Glumslöv    Skåne  Övra Glumslöv 37:4  Glumslöv 100  Boplatsområde
# ...
